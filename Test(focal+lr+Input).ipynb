# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import pandas as pd
import PIL
from PIL import Image
import pathlib
import os
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.losses import *
import requests
# !pip install pyunpack patool
import pyunpack
import matplotlib.pyplot as plt
from tensorflow.keras import backend as K
from tensorflow.keras.callbacks import ModelCheckpoint
import sys
from tensorflow.keras.optimizers import Adam
# !pip install rarfile segmentation-models git+https://github.com/davej23/image-segmentation-keras.git rioxarray
from rarfile import RarFile
import segmentation_models as sm
from keras.applications import vgg16
from sklearn.metrics import *
import rioxarray as rxr
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import cv2
import PIL.Image
import math
# Out:
# 2025-12-11 23:13:22.995252: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-12-11 23:13:23.164579: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-11 23:13:23.201380: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-12-11 23:13:23.873883: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2025-12-11 23:13:23.873950: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2025-12-11 23:13:23.873956: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# Segmentation Models: using `keras` framework.

# %% [markdown]
# # Functions

# %%
def get_edge_from_mask(mask):
    m = (mask.squeeze() > 0).astype(np.uint8)
    kernel = np.ones((3,3), np.uint8)
    edge = cv2.morphologyEx(m, cv2.MORPH_GRADIENT, kernel)
    edge = edge.astype(np.float32)
    return edge.reshape(512,512,1)
def iou_metric(y_true, y_pred, smooth=1e-6):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred > 0.5, tf.float32) 

    intersection = tf.reduce_sum(y_true * y_pred)
    union = tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) - intersection

    return (intersection + smooth) / (union + smooth)

# %% [markdown]
# # Ingest and Process New Dataset

# %%
base_dir = r"./Nepal landslide dataset/"

# %%
# Ingest images

training_images_list = os.listdir(r"{}Training/image/".format(base_dir))
training_masks_list = []
training_images = []

for n in training_images_list:
    im = PIL.Image.open(r"{}Training/image/{}".format(base_dir, n))
    training_images.append(im)
    # Nepal uses .tiff → label uses .png
    training_masks_list.append(n[:-5] + '.png')
    
# Training masks
training_masks = []
for n in training_masks_list:
    im = PIL.Image.open(r"{}Training/label/{}".format(base_dir, n))
    training_masks.append(im)

# -------------------------
# Test images
# -------------------------
test_images_list = os.listdir(r"{}Test/image/".format(base_dir))
test_masks_list = []
test_images = []

for n in test_images_list:
    im = PIL.Image.open(r"{}Test/image/{}".format(base_dir, n))
    test_images.append(im)
    test_masks_list.append(n[:-5] + '.png')

# Test mask
test_masks = []
for n in test_masks_list:
    im = PIL.Image.open(r"{}Test/mask/{}".format(base_dir, n))
    test_masks.append(im)
    
# -------------------------
# Validation images
# -------------------------
validation_images_list = os.listdir(r"{}Validation/images/".format(base_dir))
validation_masks_list = []
validation_images = []

for n in validation_images_list:
    im = PIL.Image.open(r"{}Validation/images/{}".format(base_dir, n))
    validation_images.append(im)
    validation_masks_list.append(n[:-5] + '.png')

# Validation masks
validation_masks = []
for n in validation_masks_list:
    im = PIL.Image.open(r"{}Validation/masks/{}".format(base_dir, n))
    validation_masks.append(im)

# %%
# Pre-process (same as original, only ensure resize)
# -------------------------

# images (3-channel)
for i in range(len(training_images)):
    arr = np.array(training_images[i]) / 255
    arr = cv2.resize(arr, (512, 512))     
    arr = arr.reshape(1, 512, 512, 3)
    training_images[i] = arr.astype('float32')

# masks (1-channel)
for i in range(len(training_masks)):
    arr = np.array(training_masks[i])
    arr = cv2.resize(arr, (512, 512))    
    arr = arr.reshape(1, 512, 512, 1)
    training_masks[i] = arr.astype('int')

training_edges = []
for i in range(len(training_masks)):
    mask = training_masks[i].astype(np.uint8)
    edge = get_edge_from_mask(mask)
    training_edges.append(edge)

# # validation images
for i in range(len(validation_images)):
    arr = np.array(validation_images[i]) / 255
    arr = cv2.resize(arr, (512, 512))
    arr = arr.reshape(1, 512, 512, 3)
    validation_images[i] = arr.astype('float32')

# validation masks
for i in range(len(validation_masks)):
    arr = np.array(validation_masks[i])
    arr = cv2.resize(arr, (512, 512))
    arr = arr.reshape(1, 512, 512, 1)
    validation_masks[i] = arr.astype('int')

validation_edges = []
                          
for i in range(len(validation_masks)):
    mask = validation_masks[i].astype(np.uint8)
    edge = get_edge_from_mask(mask)
    validation_edges.append(edge)

# test images
for i in range(len(test_images)):
    arr = np.array(test_images[i]) / 255
    arr = cv2.resize(arr, (512, 512))
    arr = arr.reshape(1, 512, 512, 3)
    test_images[i] = arr.astype('float32')
# test masks
for i in range(len(test_masks)):
    arr = np.array(test_masks[i])
    arr = cv2.resize(arr, (512, 512))
    arr = arr.reshape(1, 512, 512, 1)
    test_masks[i] = arr.astype('int')

# %%
validation_Nepal_landslide_dataset = tf.data.Dataset.from_tensor_slices((validation_images, validation_masks))
# Out:
# 2025-12-11 23:13:27.756526: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-12-11 23:13:28.377012: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22168 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:d1:00.0, compute capability: 8.6

# %%
def mask_stats(masks):
    # masks: numpy array (N,H,W,1) or list
    a = np.array(masks)
    if a.ndim==4 and a.shape[-1]==1:
        a = a[...,0]
    flat = a.flatten()
    unique, counts = np.unique(flat, return_counts=True)
    freq = dict(zip(unique.tolist(), counts.tolist()))
    total = flat.size
    print("unique values & counts:", freq)
    print("total pixels:", total)
    for k,v in freq.items():
        print(f"value {k}: {v} pixels, ratio {v/total:.6f}")
    return freq

mask_stats(training_masks)
mask_stats(validation_masks)
# Out:
# unique values & counts: {0: 59831463, 1: 461657}
# total pixels: 60293120
# value 0: 59831463 pixels, ratio 0.992343
# value 1: 461657 pixels, ratio 0.007657
# unique values & counts: {0: 9079805, 1: 95235}
# total pixels: 9175040
# value 0: 9079805 pixels, ratio 0.989620
# value 1: 95235 pixels, ratio 0.010380
# {0: 9079805, 1: 95235}

# %%
# Data loader/generator from: https://github.com/bragagnololu/UNet-defmapping.git
#

def adjustData(img, mask, num_class):
  
    mask[mask > 0.3] = 1 # FOREST
    mask[mask <= 0.3] = 0 # NON-FOREST

    return (img,mask)

def trainGenerator(batch_size, images, edges, masks, aug_dict):
    data_gen = ImageDataGenerator(**aug_dict)

    img_gen  = data_gen.flow(images, batch_size=batch_size, seed=1)
    edge_gen = data_gen.flow(edges,  batch_size=batch_size, seed=1)
    mask_gen = data_gen.flow(masks,  batch_size=batch_size, seed=1)

    while True:
        batch_img  = img_gen.next()
        batch_edge = edge_gen.next()
        batch_mask = mask_gen.next()

        yield ([batch_img, batch_edge], batch_mask)

# %%
t_images = np.stack(training_images)
t_masks = np.stack(training_masks)
t_images = np.squeeze(t_images, axis=1)
t_edges = np.stack(training_edges)
t_masks  = np.squeeze(t_masks, axis=1)


v_edges = np.stack(validation_edges)
v_images = np.stack(validation_images)
v_masks = np.stack(validation_masks)
v_images = np.squeeze(v_images, axis=1)
v_masks  = np.squeeze(v_masks, axis=1)


data_gen_args = dict(
    rotation_range=10,
    width_shift_range=0.05,
    height_shift_range=0.05,
    zoom_range=0.05,
    horizontal_flip=True,
    vertical_flip=True,
    fill_mode='reflect',
)

train = trainGenerator(1, t_images, t_edges, t_masks, data_gen_args)

# %%
BETA = 0.95
SMOOTH_TERM = 1e-7

def dice_coef(y_true, y_pred, smooth=SMOOTH_TERM):
    y_true_float = K.cast(y_true, 'float32') 
    
    y_true_f = K.flatten(y_true_float)
    y_pred_f = K.flatten(y_pred)
    
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def dice_loss(y_true, y_pred):
    return 1 - dice_coef(y_true, y_pred)
    
def focal_tversky_loss(y_true, y_pred, alpha=0.7, beta=0.3, gamma=2.0):
    y_true = K.cast(y_true, 'float32')
    y_pred = K.cast(y_pred, 'float32')


    TP = K.sum(y_true * y_pred)
    FP = K.sum((1 - y_true) * y_pred)
    FN = K.sum(y_true * (1 - y_pred))

    tversky = (TP + 1e-7) / (TP + alpha*FN + beta*FP + 1e-7)
    focal_tversky = K.pow((1 - tversky), gamma)

    return focal_tversky

# %%
from tensorflow.keras.callbacks import Callback
from tensorflow.keras.callbacks import ReduceLROnPlateau

reduce_lr = ReduceLROnPlateau(
    monitor='val_iou_metric', 
    mode='max',                
    factor=0.5,
    patience=7,
    verbose=1,
    min_lr=1e-7
)

# %% [markdown]
# # Models

# %% [markdown]
# ## U-Net

# %%
'''
  Convolutional block with set parameters and activation layer after
'''

def convBlock(input, filters, kernel, kernel_init='he_normal', act='relu', transpose=False):
  if transpose == False:
    #conv = ZeroPadding2D((1,1))(input)
    conv = Conv2D(filters, kernel, padding = 'same', kernel_initializer = kernel_init)(input)
  else:
    #conv = ZeroPadding2D((1,1))(input)
    conv = Conv2DTranspose(filters, kernel, padding = 'same', kernel_initializer = kernel_init)(input)

  conv = Activation(act)(conv)
  return conv
  
'''
  U-Net model
'''

def UNet(trained_weights = None, input_size = (512,512,3), drop_rate = 0.25, lr=0.0001):

    ## Can add pretrained weights by specifying 'trained_weights'

    # Input layer
    input_img = Input((512,512,3))
    input_edge = Input((512,512,1))
    inputs = Concatenate(axis=-1)([input_img, input_edge])

    ## Contraction phase
    conv1 = convBlock(inputs, 64, 3)
    conv1 = convBlock(conv1, 64, 3)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = convBlock(pool1, 128, 3)
    conv2 = convBlock(conv2, 128, 3)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    #drop2 = Dropout(drop_rate)(pool2)

    conv3 = convBlock(pool2, 256, 3)
    conv3 = convBlock(conv3, 256, 3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    #drop3 = Dropout(drop_rate)(pool3)

    conv4 = convBlock(pool3, 512, 3)
    conv4 = convBlock(conv4, 512, 3)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)
    #drop4 = Dropout(drop_rate)(pool4)

    conv5 = convBlock(pool4, 1024, 3)
    conv5 = convBlock(conv5, 1024, 3)

    ## Expansion phase
    up6 = (Conv2DTranspose(512, kernel_size=2, strides=2, kernel_initializer='he_normal')(conv5))
    merge6 = concatenate([conv4,up6])
    conv6 = convBlock(merge6, 512, 3)
    conv6 = convBlock(conv6, 512, 3)
    #conv6 = Dropout(drop_rate)(conv6)

    up7 = (Conv2DTranspose(256, kernel_size=2, strides=2, kernel_initializer='he_normal')(conv6))
    merge7 = concatenate([conv3,up7])
    conv7 = convBlock(merge7, 256, 3)
    conv7 = convBlock(conv7, 256, 3)
    #conv7 = Dropout(drop_rate)(conv7)

    up8 = (Conv2DTranspose(128, kernel_size=2, strides=2, kernel_initializer='he_normal')(conv7))
    merge8 = concatenate([conv2,up8])
    conv8 = convBlock(merge8, 128, 3)
    conv8 = convBlock(conv8, 128, 3)
    #conv8 = Dropout(drop_rate)(conv8)

    up9 = (Conv2DTranspose(64, kernel_size=2, strides=2, kernel_initializer='he_normal')(conv8))
    merge9 = concatenate([conv1,up9])
    conv9 = convBlock(merge9, 64, 3)
    conv9 = convBlock(conv9, 64, 3)

    # Output layer
    conv10 = convBlock(conv9, 1, 1, act='sigmoid')

    model = Model([input_img, input_edge], conv10)

    # model.compile(optimizer = Adam(learning_rate = lr), loss = 'binary_crossentropy', metrics = ['accuracy', 'mse'])
    model.compile(optimizer = Adam(learning_rate = lr), loss = focal_tversky_loss, metrics = ['accuracy', iou_metric])
    if trained_weights != None:
    	model.load_weights(trained_weights)

    return model

# %%
# Print model layers and number of parameters
UNet().summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 512, 512, 3  0           []
#                                 )]
#
#  input_2 (InputLayer)           [(None, 512, 512, 1  0           []
#                                 )]
#
#  concatenate (Concatenate)      (None, 512, 512, 4)  0           ['input_1[0][0]',
#                                                                   'input_2[0][0]']
#
#  conv2d (Conv2D)                (None, 512, 512, 64  2368        ['concatenate[0][0]']
#                                 )
#
#  activation (Activation)        (None, 512, 512, 64  0           ['conv2d[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 512, 512, 64  36928       ['activation[0][0]']
#                                 )
#
#  activation_1 (Activation)      (None, 512, 512, 64  0           ['conv2d_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 256, 256, 64  0           ['activation_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 256, 256, 12  73856       ['max_pooling2d[0][0]']
#                                 8)
#
#  activation_2 (Activation)      (None, 256, 256, 12  0           ['conv2d_2[0][0]']
#                                 8)
#
#  conv2d_3 (Conv2D)              (None, 256, 256, 12  147584      ['activation_2[0][0]']
#                                 8)
#
#  activation_3 (Activation)      (None, 256, 256, 12  0           ['conv2d_3[0][0]']
#                                 8)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 128, 128, 12  0          ['activation_3[0][0]']
#                                 8)
#
#  conv2d_4 (Conv2D)              (None, 128, 128, 25  295168      ['max_pooling2d_1[0][0]']
#                                 6)
#
#  activation_4 (Activation)      (None, 128, 128, 25  0           ['conv2d_4[0][0]']
#                                 6)
#
#  conv2d_5 (Conv2D)              (None, 128, 128, 25  590080      ['activation_4[0][0]']
#                                 6)
#
#  activation_5 (Activation)      (None, 128, 128, 25  0           ['conv2d_5[0][0]']
#                                 6)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 64, 64, 256)  0          ['activation_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 64, 64, 512)  1180160     ['max_pooling2d_2[0][0]']
#
#  activation_6 (Activation)      (None, 64, 64, 512)  0           ['conv2d_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 64, 64, 512)  2359808     ['activation_6[0][0]']
#
#  activation_7 (Activation)      (None, 64, 64, 512)  0           ['conv2d_7[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 32, 32, 512)  0          ['activation_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 32, 32, 1024  4719616     ['max_pooling2d_3[0][0]']
#                                 )
#
#  activation_8 (Activation)      (None, 32, 32, 1024  0           ['conv2d_8[0][0]']
#                                 )
#
#  conv2d_9 (Conv2D)              (None, 32, 32, 1024  9438208     ['activation_8[0][0]']
#                                 )
#
#  activation_9 (Activation)      (None, 32, 32, 1024  0           ['conv2d_9[0][0]']
#                                 )
#
#  conv2d_transpose (Conv2DTransp  (None, 64, 64, 512)  2097664    ['activation_9[0][0]']
#  ose)
#
#  concatenate_1 (Concatenate)    (None, 64, 64, 1024  0           ['activation_7[0][0]',
#                                 )                                 'conv2d_transpose[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 64, 64, 512)  4719104     ['concatenate_1[0][0]']
#
#  activation_10 (Activation)     (None, 64, 64, 512)  0           ['conv2d_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 64, 64, 512)  2359808     ['activation_10[0][0]']
#
#  activation_11 (Activation)     (None, 64, 64, 512)  0           ['conv2d_11[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 128, 128, 25  524544     ['activation_11[0][0]']
#  spose)                         6)
#
#  concatenate_2 (Concatenate)    (None, 128, 128, 51  0           ['activation_5[0][0]',
#                                 2)                                'conv2d_transpose_1[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 128, 128, 25  1179904     ['concatenate_2[0][0]']
#                                 6)
#
#  activation_12 (Activation)     (None, 128, 128, 25  0           ['conv2d_12[0][0]']
#                                 6)
#
#  conv2d_13 (Conv2D)             (None, 128, 128, 25  590080      ['activation_12[0][0]']
#                                 6)
#
#  activation_13 (Activation)     (None, 128, 128, 25  0           ['conv2d_13[0][0]']
#                                 6)
#
#  conv2d_transpose_2 (Conv2DTran  (None, 256, 256, 12  131200     ['activation_13[0][0]']
#  spose)                         8)
#
#  concatenate_3 (Concatenate)    (None, 256, 256, 25  0           ['activation_3[0][0]',
#                                 6)                                'conv2d_transpose_2[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 256, 256, 12  295040      ['concatenate_3[0][0]']
#                                 8)
#
#  activation_14 (Activation)     (None, 256, 256, 12  0           ['conv2d_14[0][0]']
#                                 8)
#
#  conv2d_15 (Conv2D)             (None, 256, 256, 12  147584      ['activation_14[0][0]']
#                                 8)
#
#  activation_15 (Activation)     (None, 256, 256, 12  0           ['conv2d_15[0][0]']
#                                 8)
#
#  conv2d_transpose_3 (Conv2DTran  (None, 512, 512, 64  32832      ['activation_15[0][0]']
#  spose)                         )
#
#  concatenate_4 (Concatenate)    (None, 512, 512, 12  0           ['activation_1[0][0]',
#                                 8)                                'conv2d_transpose_3[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 512, 512, 64  73792       ['concatenate_4[0][0]']
#                                 )
#
#  activation_16 (Activation)     (None, 512, 512, 64  0           ['conv2d_16[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 512, 512, 64  36928       ['activation_16[0][0]']
#                                 )
#
#  activation_17 (Activation)     (None, 512, 512, 64  0           ['conv2d_17[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 512, 512, 1)  65          ['activation_17[0][0]']
#
#  activation_18 (Activation)     (None, 512, 512, 1)  0           ['conv2d_18[0][0]']
#
# ==================================================================================================
# Total params: 31,032,321
# Trainable params: 31,032,321
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## Attention U-Net

# %%
'''
  Convolutional block with two conv layers and two activation layers
'''

def convBlock2(input, filters, kernel, kernel_init='he_normal', act='relu', transpose=False):
  if transpose == False:
    conv = Conv2D(filters, kernel, padding = 'same', kernel_initializer = kernel_init)(input)
    conv = Activation(act)(conv)
    conv = Conv2D(filters, kernel, padding = 'same', kernel_initializer = kernel_init)(conv)
    conv = Activation(act)(conv)
  else:
    conv = Conv2DTranspose(filters, kernel, padding = 'same', kernel_initializer = kernel_init)(input)
    conv = Activation(act)(conv)
    conv = Conv2DTranspose(filters, kernel, padding = 'same', kernel_initializer = kernel_init)(conv)
    conv = Activation(act)(conv)

  return conv
  
'''
  Attention block/mechanism
'''
def attention_block(x, gating, inter_shape, drop_rate=0.25):
   
    # Find shape of inputs
    shape_x = K.int_shape(x)
    shape_g = K.int_shape(gating)

    ## Process x vector and gating signal
    # x vector input and processing
    theta_x = Conv2D(inter_shape, (2, 2), strides=(2, 2), padding='same')(x)
    phi_g = Conv2D(inter_shape, (1, 1), padding='same')(gating)

    # match spatial size
    upsample_g = UpSampling2D(size=(theta_x.shape[1] // phi_g.shape[1],
                                    theta_x.shape[2] // phi_g.shape[2]), 
                              interpolation='bilinear')(phi_g)

    concat_xg = add([upsample_g, theta_x])
    act_xg = Activation('relu')(concat_xg)

    psi = Conv2D(1, (1, 1), padding='same')(act_xg)
    psi = Activation('sigmoid')(psi)

    # upsample attention mask to match x
    psi_up = UpSampling2D(size=(x.shape[1] // psi.shape[1],
                                x.shape[2] // psi.shape[2]), 
                          interpolation='bilinear')(psi)

    # apply attention
    y = multiply([x, psi_up])
    return y


'''
  Attention U-Net model
'''

def UNetAM(trained_weights = None, input_size = (512,512,3), drop_rate = 0.25, lr=0.0001, filter_base=16):

    ## Can add pretrained weights by specifying 'trained_weights'

    # Input layer
    input_img = Input((512,512,3))
    input_edge = Input((512,512,1))
    inputs = Concatenate(axis=-1)([input_img, input_edge])


    ## Contraction phase
    conv = convBlock2(inputs, filter_base, 3)
    #conv0 = Dropout(drop_rate)(conv0)

    conv0 = MaxPooling2D(pool_size=(2, 2))(conv)
    conv0 = convBlock2(conv0, 2 * filter_base, 3)

    pool0 = MaxPooling2D(pool_size=(2, 2))(conv0)
    conv1 = convBlock2(pool0, 4 * filter_base, 3)
    #conv1 = Dropout(drop_rate)(conv1)

    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    conv2 = convBlock2(pool1, 8 * filter_base, 3)
    #conv2 = Dropout(drop_rate)(conv2)

    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    conv3 = convBlock2(pool2, 16 * filter_base, 3)
    #conv3 = Dropout(drop_rate)(conv3)

    ## Expansion phase
    up4 = (Conv2DTranspose(8 * filter_base, kernel_size=2, strides=2, kernel_initializer='he_normal')(conv3))
    merge4 = attention_block(conv2, conv3, 8 * filter_base, drop_rate) # Attention gate
    conv4 = concatenate([up4, merge4])
    conv4 = convBlock2(conv4, 8 * filter_base, 3)

    up5 = (Conv2DTranspose(4 * filter_base, kernel_size=2, strides=2, kernel_initializer='he_normal')(conv4))
    merge5 = attention_block(conv1, conv4, 4 * filter_base, drop_rate) # Attention gate
    conv5 = concatenate([up5, merge5])
    conv5 = convBlock2(conv5, 4 * filter_base, 3)

    up6 = (Conv2DTranspose(2 * filter_base, kernel_size=2, strides=2, kernel_initializer='he_normal')(conv5))
    merge6 = attention_block(conv0, conv5, 2 * filter_base, drop_rate) # Attention gate
    conv6 = concatenate([up6, merge6])
    conv6 = convBlock2(conv6, 2 * filter_base, 3)

    up7 = (Conv2DTranspose(1 * filter_base, kernel_size=2, strides=2, kernel_initializer='he_normal')(conv6))
    merge7 = attention_block(conv, conv6, 1 * filter_base, drop_rate)
    conv7 = concatenate([up7, merge7]) 
    conv7 = convBlock2(conv7, 1 * filter_base, 3)

    ## Output layer
    out = convBlock(conv7, 1, 1, act='sigmoid')

    model = Model([input_img, input_edge], out)

    # model.compile(optimizer = Adam(learning_rate = lr), loss = 'binary_crossentropy', metrics = ['accuracy', 'mse'])
    model.compile(optimizer = Adam(learning_rate = lr), loss = focal_tversky_loss, metrics = ['accuracy', iou_metric])
    if trained_weights != None:
    	model.load_weights(trained_weights)

    return model

# %%
# Print model layers and number of parameters
UNetAM().summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 512, 512, 3  0           []
#                                 )]
#
#  input_4 (InputLayer)           [(None, 512, 512, 1  0           []
#                                 )]
#
#  concatenate_5 (Concatenate)    (None, 512, 512, 4)  0           ['input_3[0][0]',
#                                                                   'input_4[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 512, 512, 16  592         ['concatenate_5[0][0]']
#                                 )
#
#  activation_19 (Activation)     (None, 512, 512, 16  0           ['conv2d_19[0][0]']
#                                 )
#
#  conv2d_20 (Conv2D)             (None, 512, 512, 16  2320        ['activation_19[0][0]']
#                                 )
#
#  activation_20 (Activation)     (None, 512, 512, 16  0           ['conv2d_20[0][0]']
#                                 )
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 256, 256, 16  0          ['activation_20[0][0]']
#                                 )
#
#  conv2d_21 (Conv2D)             (None, 256, 256, 32  4640        ['max_pooling2d_4[0][0]']
#                                 )
#
#  activation_21 (Activation)     (None, 256, 256, 32  0           ['conv2d_21[0][0]']
#                                 )
#
#  conv2d_22 (Conv2D)             (None, 256, 256, 32  9248        ['activation_21[0][0]']
#                                 )
#
#  activation_22 (Activation)     (None, 256, 256, 32  0           ['conv2d_22[0][0]']
#                                 )
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 128, 128, 32  0          ['activation_22[0][0]']
#                                 )
#
#  conv2d_23 (Conv2D)             (None, 128, 128, 64  18496       ['max_pooling2d_5[0][0]']
#                                 )
#
#  activation_23 (Activation)     (None, 128, 128, 64  0           ['conv2d_23[0][0]']
#                                 )
#
#  conv2d_24 (Conv2D)             (None, 128, 128, 64  36928       ['activation_23[0][0]']
#                                 )
#
#  activation_24 (Activation)     (None, 128, 128, 64  0           ['conv2d_24[0][0]']
#                                 )
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 64, 64, 64)  0           ['activation_24[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 64, 64, 128)  73856       ['max_pooling2d_6[0][0]']
#
#  activation_25 (Activation)     (None, 64, 64, 128)  0           ['conv2d_25[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 64, 64, 128)  147584      ['activation_25[0][0]']
#
#  activation_26 (Activation)     (None, 64, 64, 128)  0           ['conv2d_26[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 32, 32, 128)  0          ['activation_26[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 32, 32, 256)  295168      ['max_pooling2d_7[0][0]']
#
#  activation_27 (Activation)     (None, 32, 32, 256)  0           ['conv2d_27[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 32, 32, 256)  590080      ['activation_27[0][0]']
#
#  activation_28 (Activation)     (None, 32, 32, 256)  0           ['conv2d_28[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 32, 32, 128)  32896       ['activation_28[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 32, 32, 128)  0           ['conv2d_30[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 32, 32, 128)  65664       ['activation_26[0][0]']
#
#  add (Add)                      (None, 32, 32, 128)  0           ['up_sampling2d[0][0]',
#                                                                   'conv2d_29[0][0]']
#
#  activation_29 (Activation)     (None, 32, 32, 128)  0           ['add[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 32, 32, 1)    129         ['activation_29[0][0]']
#
#  activation_30 (Activation)     (None, 32, 32, 1)    0           ['conv2d_31[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 64, 64, 1)   0           ['activation_30[0][0]']
#
#  conv2d_transpose_4 (Conv2DTran  (None, 64, 64, 128)  131200     ['activation_28[0][0]']
#  spose)
#
#  multiply (Multiply)            (None, 64, 64, 128)  0           ['activation_26[0][0]',
#                                                                   'up_sampling2d_1[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 64, 64, 256)  0           ['conv2d_transpose_4[0][0]',
#                                                                   'multiply[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 64, 64, 128)  295040      ['concatenate_6[0][0]']
#
#  activation_31 (Activation)     (None, 64, 64, 128)  0           ['conv2d_32[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 64, 64, 128)  147584      ['activation_31[0][0]']
#
#  activation_32 (Activation)     (None, 64, 64, 128)  0           ['conv2d_33[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 64, 64, 64)   8256        ['activation_32[0][0]']
#
#  up_sampling2d_2 (UpSampling2D)  (None, 64, 64, 64)  0           ['conv2d_35[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 64, 64, 64)   16448       ['activation_24[0][0]']
#
#  add_1 (Add)                    (None, 64, 64, 64)   0           ['up_sampling2d_2[0][0]',
#                                                                   'conv2d_34[0][0]']
#
#  activation_33 (Activation)     (None, 64, 64, 64)   0           ['add_1[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 64, 64, 1)    65          ['activation_33[0][0]']
#
#  activation_34 (Activation)     (None, 64, 64, 1)    0           ['conv2d_36[0][0]']
#
#  up_sampling2d_3 (UpSampling2D)  (None, 128, 128, 1)  0          ['activation_34[0][0]']
#
#  conv2d_transpose_5 (Conv2DTran  (None, 128, 128, 64  32832      ['activation_32[0][0]']
#  spose)                         )
#
#  multiply_1 (Multiply)          (None, 128, 128, 64  0           ['activation_24[0][0]',
#                                 )                                 'up_sampling2d_3[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 128, 128, 12  0           ['conv2d_transpose_5[0][0]',
#                                 8)                                'multiply_1[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 128, 128, 64  73792       ['concatenate_7[0][0]']
#                                 )
#
#  activation_35 (Activation)     (None, 128, 128, 64  0           ['conv2d_37[0][0]']
#                                 )
#
#  conv2d_38 (Conv2D)             (None, 128, 128, 64  36928       ['activation_35[0][0]']
#                                 )
#
#  activation_36 (Activation)     (None, 128, 128, 64  0           ['conv2d_38[0][0]']
#                                 )
#
#  conv2d_40 (Conv2D)             (None, 128, 128, 32  2080        ['activation_36[0][0]']
#                                 )
#
#  up_sampling2d_4 (UpSampling2D)  (None, 128, 128, 32  0          ['conv2d_40[0][0]']
#                                 )
#
#  conv2d_39 (Conv2D)             (None, 128, 128, 32  4128        ['activation_22[0][0]']
#                                 )
#
#  add_2 (Add)                    (None, 128, 128, 32  0           ['up_sampling2d_4[0][0]',
#                                 )                                 'conv2d_39[0][0]']
#
#  activation_37 (Activation)     (None, 128, 128, 32  0           ['add_2[0][0]']
#                                 )
#
#  conv2d_41 (Conv2D)             (None, 128, 128, 1)  33          ['activation_37[0][0]']
#
#  activation_38 (Activation)     (None, 128, 128, 1)  0           ['conv2d_41[0][0]']
#
#  up_sampling2d_5 (UpSampling2D)  (None, 256, 256, 1)  0          ['activation_38[0][0]']
#
#  conv2d_transpose_6 (Conv2DTran  (None, 256, 256, 32  8224       ['activation_36[0][0]']
#  spose)                         )
#
#  multiply_2 (Multiply)          (None, 256, 256, 32  0           ['activation_22[0][0]',
#                                 )                                 'up_sampling2d_5[0][0]']
#
#  concatenate_8 (Concatenate)    (None, 256, 256, 64  0           ['conv2d_transpose_6[0][0]',
#                                 )                                 'multiply_2[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 256, 256, 32  18464       ['concatenate_8[0][0]']
#                                 )
#
#  activation_39 (Activation)     (None, 256, 256, 32  0           ['conv2d_42[0][0]']
#                                 )
#
#  conv2d_43 (Conv2D)             (None, 256, 256, 32  9248        ['activation_39[0][0]']
#                                 )
#
#  activation_40 (Activation)     (None, 256, 256, 32  0           ['conv2d_43[0][0]']
#                                 )
#
#  conv2d_45 (Conv2D)             (None, 256, 256, 16  528         ['activation_40[0][0]']
#                                 )
#
#  up_sampling2d_6 (UpSampling2D)  (None, 256, 256, 16  0          ['conv2d_45[0][0]']
#                                 )
#
#  conv2d_44 (Conv2D)             (None, 256, 256, 16  1040        ['activation_20[0][0]']
#                                 )
#
#  add_3 (Add)                    (None, 256, 256, 16  0           ['up_sampling2d_6[0][0]',
#                                 )                                 'conv2d_44[0][0]']
#
#  activation_41 (Activation)     (None, 256, 256, 16  0           ['add_3[0][0]']
#                                 )
#
#  conv2d_46 (Conv2D)             (None, 256, 256, 1)  17          ['activation_41[0][0]']
#
#  activation_42 (Activation)     (None, 256, 256, 1)  0           ['conv2d_46[0][0]']
#
#  up_sampling2d_7 (UpSampling2D)  (None, 512, 512, 1)  0          ['activation_42[0][0]']
#
#  conv2d_transpose_7 (Conv2DTran  (None, 512, 512, 16  2064       ['activation_40[0][0]']
#  spose)                         )
#
#  multiply_3 (Multiply)          (None, 512, 512, 16  0           ['activation_20[0][0]',
#                                 )                                 'up_sampling2d_7[0][0]']
#
#  concatenate_9 (Concatenate)    (None, 512, 512, 32  0           ['conv2d_transpose_7[0][0]',
#                                 )                                 'multiply_3[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 512, 512, 16  4624        ['concatenate_9[0][0]']
#                                 )
#
#  activation_43 (Activation)     (None, 512, 512, 16  0           ['conv2d_47[0][0]']
#                                 )
#
#  conv2d_48 (Conv2D)             (None, 512, 512, 16  2320        ['activation_43[0][0]']
#                                 )
#
#  activation_44 (Activation)     (None, 512, 512, 16  0           ['conv2d_48[0][0]']
#                                 )
#
#  conv2d_49 (Conv2D)             (None, 512, 512, 1)  17          ['activation_44[0][0]']
#
#  activation_45 (Activation)     (None, 512, 512, 1)  0           ['conv2d_49[0][0]']
#
# ==================================================================================================
# Total params: 2,072,533
# Trainable params: 2,072,533
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# # Train on New feature data

# %%
# Train U-Net with generator
model_unet = UNet(lr=0.000025)
save_model = ModelCheckpoint('unet-3d.hdf5', monitor='val_iou_metric',verbose=1, save_best_only=True, mode='max')


train = trainGenerator(1, t_images, t_edges, t_masks, data_gen_args)
model_unet.fit(
    train,
    steps_per_epoch=230,
    epochs=50,
    validation_data=([v_images, v_edges], v_masks),
    callbacks=[save_model, reduce_lr]
)
# Out:
# Epoch 1/50
# 2025-12-11 23:13:55.612801: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8101
# 2025-12-11 23:13:58.454100: I tensorflow/stream_executor/cuda/cuda_blas.cc:1614] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 230/230 [==============================] - ETA: 0s - loss: 0.3008 - accuracy: 0.9058 - iou_metric: 0.4298
# Epoch 1: val_iou_metric improved from -inf to 0.45389, saving model to unet-3d.hdf5
# 230/230 [==============================] - 50s 173ms/step - loss: 0.3008 - accuracy: 0.9058 - iou_metric: 0.4298 - val_loss: 0.0662 - val_accuracy: 0.9889 - val_iou_metric: 0.4539 - lr: 2.5000e-05
# Epoch 2/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0388 - accuracy: 0.9950 - iou_metric: 0.6504
# Epoch 2: val_iou_metric improved from 0.45389 to 0.66696, saving model to unet-3d.hdf5
# 230/230 [==============================] - 18s 77ms/step - loss: 0.0388 - accuracy: 0.9950 - iou_metric: 0.6504 - val_loss: 0.0239 - val_accuracy: 0.9955 - val_iou_metric: 0.6670 - lr: 2.5000e-05
# Epoch 3/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0255 - accuracy: 0.9955 - iou_metric: 0.6968
# Epoch 3: val_iou_metric improved from 0.66696 to 0.67495, saving model to unet-3d.hdf5
# 230/230 [==============================] - 18s 80ms/step - loss: 0.0255 - accuracy: 0.9955 - iou_metric: 0.6968 - val_loss: 0.0184 - val_accuracy: 0.9955 - val_iou_metric: 0.6749 - lr: 2.5000e-05
# Epoch 4/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0207 - accuracy: 0.9958 - iou_metric: 0.7186
# Epoch 4: val_iou_metric improved from 0.67495 to 0.71651, saving model to unet-3d.hdf5
# 230/230 [==============================] - 18s 80ms/step - loss: 0.0207 - accuracy: 0.9958 - iou_metric: 0.7186 - val_loss: 0.0127 - val_accuracy: 0.9963 - val_iou_metric: 0.7165 - lr: 2.5000e-05
# Epoch 5/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0160 - accuracy: 0.9961 - iou_metric: 0.7471
# Epoch 5: val_iou_metric improved from 0.71651 to 0.72942, saving model to unet-3d.hdf5
# 230/230 [==============================] - 19s 81ms/step - loss: 0.0160 - accuracy: 0.9961 - iou_metric: 0.7471 - val_loss: 0.0082 - val_accuracy: 0.9966 - val_iou_metric: 0.7294 - lr: 2.5000e-05
# Epoch 6/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0109 - accuracy: 0.9968 - iou_metric: 0.7812
# Epoch 6: val_iou_metric did not improve from 0.72942
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0109 - accuracy: 0.9968 - iou_metric: 0.7812 - val_loss: 0.0252 - val_accuracy: 0.9934 - val_iou_metric: 0.5766 - lr: 2.5000e-05
# Epoch 7/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0141 - accuracy: 0.9967 - iou_metric: 0.7784
# Epoch 7: val_iou_metric did not improve from 0.72942
# 230/230 [==============================] - 18s 76ms/step - loss: 0.0141 - accuracy: 0.9967 - iou_metric: 0.7784 - val_loss: 0.0175 - val_accuracy: 0.9952 - val_iou_metric: 0.6598 - lr: 2.5000e-05
# Epoch 8/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0089 - accuracy: 0.9970 - iou_metric: 0.8060
# Epoch 8: val_iou_metric improved from 0.72942 to 0.83290, saving model to unet-3d.hdf5
# 230/230 [==============================] - 18s 80ms/step - loss: 0.0089 - accuracy: 0.9970 - iou_metric: 0.8060 - val_loss: 0.0032 - val_accuracy: 0.9982 - val_iou_metric: 0.8329 - lr: 2.5000e-05
# Epoch 9/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0067 - accuracy: 0.9973 - iou_metric: 0.8215
# Epoch 9: val_iou_metric did not improve from 0.83290
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0067 - accuracy: 0.9973 - iou_metric: 0.8215 - val_loss: 0.0040 - val_accuracy: 0.9978 - val_iou_metric: 0.8079 - lr: 2.5000e-05
# Epoch 10/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0069 - accuracy: 0.9973 - iou_metric: 0.8250
# Epoch 10: val_iou_metric did not improve from 0.83290
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0069 - accuracy: 0.9973 - iou_metric: 0.8250 - val_loss: 0.0032 - val_accuracy: 0.9981 - val_iou_metric: 0.8280 - lr: 2.5000e-05
# Epoch 11/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0046 - accuracy: 0.9976 - iou_metric: 0.8457
# Epoch 11: val_iou_metric improved from 0.83290 to 0.86119, saving model to unet-3d.hdf5
# 230/230 [==============================] - 18s 80ms/step - loss: 0.0046 - accuracy: 0.9976 - iou_metric: 0.8457 - val_loss: 0.0021 - val_accuracy: 0.9985 - val_iou_metric: 0.8612 - lr: 2.5000e-05
# Epoch 12/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0060 - accuracy: 0.9975 - iou_metric: 0.8311
# Epoch 12: val_iou_metric improved from 0.86119 to 0.86951, saving model to unet-3d.hdf5
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0060 - accuracy: 0.9975 - iou_metric: 0.8311 - val_loss: 0.0019 - val_accuracy: 0.9986 - val_iou_metric: 0.8695 - lr: 2.5000e-05
# Epoch 13/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0038 - accuracy: 0.9978 - iou_metric: 0.8594
# Epoch 13: val_iou_metric improved from 0.86951 to 0.88282, saving model to unet-3d.hdf5
# 230/230 [==============================] - 18s 80ms/step - loss: 0.0038 - accuracy: 0.9978 - iou_metric: 0.8594 - val_loss: 0.0016 - val_accuracy: 0.9988 - val_iou_metric: 0.8828 - lr: 2.5000e-05
# Epoch 14/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0078 - accuracy: 0.9973 - iou_metric: 0.8214
# Epoch 14: val_iou_metric did not improve from 0.88282
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0078 - accuracy: 0.9973 - iou_metric: 0.8214 - val_loss: 0.0023 - val_accuracy: 0.9984 - val_iou_metric: 0.8545 - lr: 2.5000e-05
# Epoch 15/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0042 - accuracy: 0.9977 - iou_metric: 0.8547
# Epoch 15: val_iou_metric improved from 0.88282 to 0.88344, saving model to unet-3d.hdf5
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0042 - accuracy: 0.9977 - iou_metric: 0.8547 - val_loss: 0.0017 - val_accuracy: 0.9988 - val_iou_metric: 0.8834 - lr: 2.5000e-05
# Epoch 16/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0037 - accuracy: 0.9978 - iou_metric: 0.8645
# Epoch 16: val_iou_metric did not improve from 0.88344
# 230/230 [==============================] - 18s 76ms/step - loss: 0.0037 - accuracy: 0.9978 - iou_metric: 0.8645 - val_loss: 0.0023 - val_accuracy: 0.9984 - val_iou_metric: 0.8569 - lr: 2.5000e-05
# Epoch 17/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0088 - accuracy: 0.9973 - iou_metric: 0.8465
# Epoch 17: val_iou_metric did not improve from 0.88344
# 230/230 [==============================] - 18s 77ms/step - loss: 0.0088 - accuracy: 0.9973 - iou_metric: 0.8465 - val_loss: 0.0021 - val_accuracy: 0.9984 - val_iou_metric: 0.8476 - lr: 2.5000e-05
# Epoch 18/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0060 - accuracy: 0.9974 - iou_metric: 0.8515
# Epoch 18: val_iou_metric improved from 0.88344 to 0.88857, saving model to unet-3d.hdf5
# 230/230 [==============================] - 18s 76ms/step - loss: 0.0060 - accuracy: 0.9974 - iou_metric: 0.8515 - val_loss: 0.0011 - val_accuracy: 0.9989 - val_iou_metric: 0.8886 - lr: 2.5000e-05
# Epoch 19/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0045 - accuracy: 0.9978 - iou_metric: 0.8603
# Epoch 19: val_iou_metric did not improve from 0.88857
# 230/230 [==============================] - 18s 77ms/step - loss: 0.0045 - accuracy: 0.9978 - iou_metric: 0.8603 - val_loss: 0.0028 - val_accuracy: 0.9984 - val_iou_metric: 0.8550 - lr: 2.5000e-05
# Epoch 20/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0042 - accuracy: 0.9976 - iou_metric: 0.8625
# Epoch 20: val_iou_metric improved from 0.88857 to 0.90106, saving model to unet-3d.hdf5
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0042 - accuracy: 0.9976 - iou_metric: 0.8625 - val_loss: 0.0011 - val_accuracy: 0.9990 - val_iou_metric: 0.9011 - lr: 2.5000e-05
# Epoch 21/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0027 - accuracy: 0.9980 - iou_metric: 0.8797
# Epoch 21: val_iou_metric did not improve from 0.90106
# 230/230 [==============================] - 18s 77ms/step - loss: 0.0027 - accuracy: 0.9980 - iou_metric: 0.8797 - val_loss: 0.0011 - val_accuracy: 0.9989 - val_iou_metric: 0.8944 - lr: 2.5000e-05
# Epoch 22/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0026 - accuracy: 0.9980 - iou_metric: 0.8829
# Epoch 22: val_iou_metric improved from 0.90106 to 0.91360, saving model to unet-3d.hdf5
# 230/230 [==============================] - 18s 80ms/step - loss: 0.0026 - accuracy: 0.9980 - iou_metric: 0.8829 - val_loss: 7.3192e-04 - val_accuracy: 0.9991 - val_iou_metric: 0.9136 - lr: 2.5000e-05
# Epoch 23/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0025 - accuracy: 0.9980 - iou_metric: 0.8855
# Epoch 23: val_iou_metric did not improve from 0.91360
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0025 - accuracy: 0.9980 - iou_metric: 0.8855 - val_loss: 0.0011 - val_accuracy: 0.9989 - val_iou_metric: 0.8976 - lr: 2.5000e-05
# Epoch 24/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0023 - accuracy: 0.9980 - iou_metric: 0.8884
# Epoch 24: val_iou_metric did not improve from 0.91360
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0023 - accuracy: 0.9980 - iou_metric: 0.8884 - val_loss: 0.0012 - val_accuracy: 0.9989 - val_iou_metric: 0.8907 - lr: 2.5000e-05
# Epoch 25/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0058 - accuracy: 0.9975 - iou_metric: 0.8604
# Epoch 25: val_iou_metric did not improve from 0.91360
# 230/230 [==============================] - 17s 75ms/step - loss: 0.0058 - accuracy: 0.9975 - iou_metric: 0.8604 - val_loss: 0.0013 - val_accuracy: 0.9988 - val_iou_metric: 0.8885 - lr: 2.5000e-05
# Epoch 26/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0047 - accuracy: 0.9976 - iou_metric: 0.8603
# Epoch 26: val_iou_metric did not improve from 0.91360
# 230/230 [==============================] - 17s 76ms/step - loss: 0.0047 - accuracy: 0.9976 - iou_metric: 0.8603 - val_loss: 0.0011 - val_accuracy: 0.9989 - val_iou_metric: 0.8958 - lr: 2.5000e-05
# Epoch 27/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0025 - accuracy: 0.9979 - iou_metric: 0.8850
# Epoch 27: val_iou_metric improved from 0.91360 to 0.91951, saving model to unet-3d.hdf5
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0025 - accuracy: 0.9979 - iou_metric: 0.8850 - val_loss: 6.3145e-04 - val_accuracy: 0.9992 - val_iou_metric: 0.9195 - lr: 2.5000e-05
# Epoch 28/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0022 - accuracy: 0.9981 - iou_metric: 0.8917
# Epoch 28: val_iou_metric improved from 0.91951 to 0.92670, saving model to unet-3d.hdf5
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0022 - accuracy: 0.9981 - iou_metric: 0.8917 - val_loss: 5.4660e-04 - val_accuracy: 0.9993 - val_iou_metric: 0.9267 - lr: 2.5000e-05
# Epoch 29/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0021 - accuracy: 0.9981 - iou_metric: 0.8935
# Epoch 29: val_iou_metric improved from 0.92670 to 0.93070, saving model to unet-3d.hdf5
# 230/230 [==============================] - 18s 80ms/step - loss: 0.0021 - accuracy: 0.9981 - iou_metric: 0.8935 - val_loss: 4.4670e-04 - val_accuracy: 0.9993 - val_iou_metric: 0.9307 - lr: 2.5000e-05
# Epoch 30/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0022 - accuracy: 0.9980 - iou_metric: 0.8913
# Epoch 30: val_iou_metric improved from 0.93070 to 0.93357, saving model to unet-3d.hdf5
# 230/230 [==============================] - 19s 81ms/step - loss: 0.0022 - accuracy: 0.9980 - iou_metric: 0.8913 - val_loss: 4.8502e-04 - val_accuracy: 0.9993 - val_iou_metric: 0.9336 - lr: 2.5000e-05
# Epoch 31/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0027 - accuracy: 0.9980 - iou_metric: 0.8904
# Epoch 31: val_iou_metric did not improve from 0.93357
# 230/230 [==============================] - 18s 77ms/step - loss: 0.0027 - accuracy: 0.9980 - iou_metric: 0.8904 - val_loss: 5.2038e-04 - val_accuracy: 0.9992 - val_iou_metric: 0.9237 - lr: 2.5000e-05
# Epoch 32/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 0.9981 - iou_metric: 0.8990
# Epoch 32: val_iou_metric improved from 0.93357 to 0.94230, saving model to unet-3d.hdf5
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0019 - accuracy: 0.9981 - iou_metric: 0.8990 - val_loss: 3.3015e-04 - val_accuracy: 0.9994 - val_iou_metric: 0.9423 - lr: 2.5000e-05
# Epoch 33/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 0.9981 - iou_metric: 0.9002
# Epoch 33: val_iou_metric improved from 0.94230 to 0.94252, saving model to unet-3d.hdf5
# 230/230 [==============================] - 18s 80ms/step - loss: 0.0019 - accuracy: 0.9981 - iou_metric: 0.9002 - val_loss: 3.0403e-04 - val_accuracy: 0.9994 - val_iou_metric: 0.9425 - lr: 2.5000e-05
# Epoch 34/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0017 - accuracy: 0.9982 - iou_metric: 0.9029
# Epoch 34: val_iou_metric did not improve from 0.94252
# 230/230 [==============================] - 18s 77ms/step - loss: 0.0017 - accuracy: 0.9982 - iou_metric: 0.9029 - val_loss: 4.1189e-04 - val_accuracy: 0.9994 - val_iou_metric: 0.9365 - lr: 2.5000e-05
# Epoch 35/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0017 - accuracy: 0.9982 - iou_metric: 0.9046
# Epoch 35: val_iou_metric did not improve from 0.94252
# 230/230 [==============================] - 17s 76ms/step - loss: 0.0017 - accuracy: 0.9982 - iou_metric: 0.9046 - val_loss: 4.2648e-04 - val_accuracy: 0.9994 - val_iou_metric: 0.9379 - lr: 2.5000e-05
# Epoch 36/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 0.9982 - iou_metric: 0.9066
# Epoch 36: val_iou_metric did not improve from 0.94252
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0016 - accuracy: 0.9982 - iou_metric: 0.9066 - val_loss: 3.1968e-04 - val_accuracy: 0.9994 - val_iou_metric: 0.9367 - lr: 2.5000e-05
# Epoch 37/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 0.9982 - iou_metric: 0.9073
# Epoch 37: val_iou_metric improved from 0.94252 to 0.94714, saving model to unet-3d.hdf5
# 230/230 [==============================] - 19s 83ms/step - loss: 0.0016 - accuracy: 0.9982 - iou_metric: 0.9073 - val_loss: 2.4039e-04 - val_accuracy: 0.9995 - val_iou_metric: 0.9471 - lr: 2.5000e-05
# Epoch 38/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0023 - accuracy: 0.9980 - iou_metric: 0.8948
# Epoch 38: val_iou_metric did not improve from 0.94714
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0023 - accuracy: 0.9980 - iou_metric: 0.8948 - val_loss: 5.9258e-04 - val_accuracy: 0.9992 - val_iou_metric: 0.9153 - lr: 2.5000e-05
# Epoch 39/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 0.9982 - iou_metric: 0.9064
# Epoch 39: val_iou_metric improved from 0.94714 to 0.95178, saving model to unet-3d.hdf5
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0016 - accuracy: 0.9982 - iou_metric: 0.9064 - val_loss: 2.0866e-04 - val_accuracy: 0.9995 - val_iou_metric: 0.9518 - lr: 2.5000e-05
# Epoch 40/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0015 - accuracy: 0.9983 - iou_metric: 0.9090
# Epoch 40: val_iou_metric did not improve from 0.95178
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0015 - accuracy: 0.9983 - iou_metric: 0.9090 - val_loss: 2.0327e-04 - val_accuracy: 0.9995 - val_iou_metric: 0.9514 - lr: 2.5000e-05
# Epoch 41/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 0.9983 - iou_metric: 0.9113
# Epoch 41: val_iou_metric did not improve from 0.95178
# 230/230 [==============================] - 17s 75ms/step - loss: 0.0014 - accuracy: 0.9983 - iou_metric: 0.9113 - val_loss: 2.1716e-04 - val_accuracy: 0.9995 - val_iou_metric: 0.9480 - lr: 2.5000e-05
# Epoch 42/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 0.9983 - iou_metric: 0.9133
# Epoch 42: val_iou_metric did not improve from 0.95178
# 230/230 [==============================] - 17s 74ms/step - loss: 0.0014 - accuracy: 0.9983 - iou_metric: 0.9133 - val_loss: 1.8167e-04 - val_accuracy: 0.9995 - val_iou_metric: 0.9516 - lr: 2.5000e-05
# Epoch 43/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 0.9983 - iou_metric: 0.9115
# Epoch 43: val_iou_metric did not improve from 0.95178
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0014 - accuracy: 0.9983 - iou_metric: 0.9115 - val_loss: 9.0901e-04 - val_accuracy: 0.9989 - val_iou_metric: 0.8964 - lr: 2.5000e-05
# Epoch 44/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 0.9983 - iou_metric: 0.9119
# Epoch 44: val_iou_metric did not improve from 0.95178
# 230/230 [==============================] - 18s 76ms/step - loss: 0.0014 - accuracy: 0.9983 - iou_metric: 0.9119 - val_loss: 2.2487e-04 - val_accuracy: 0.9995 - val_iou_metric: 0.9464 - lr: 2.5000e-05
# Epoch 45/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0106 - accuracy: 0.9964 - iou_metric: 0.8597
# Epoch 45: val_iou_metric did not improve from 0.95178
# 230/230 [==============================] - 17s 75ms/step - loss: 0.0106 - accuracy: 0.9964 - iou_metric: 0.8597 - val_loss: 0.0014 - val_accuracy: 0.9987 - val_iou_metric: 0.8577 - lr: 2.5000e-05
# Epoch 46/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0022 - accuracy: 0.9980 - iou_metric: 0.8983
# Epoch 46: val_iou_metric did not improve from 0.95178
#
# Epoch 46: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 230/230 [==============================] - 18s 80ms/step - loss: 0.0022 - accuracy: 0.9980 - iou_metric: 0.8983 - val_loss: 6.3469e-04 - val_accuracy: 0.9992 - val_iou_metric: 0.9078 - lr: 2.5000e-05
# Epoch 47/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0017 - accuracy: 0.9982 - iou_metric: 0.9066
# Epoch 47: val_iou_metric did not improve from 0.95178
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0017 - accuracy: 0.9982 - iou_metric: 0.9066 - val_loss: 2.2222e-04 - val_accuracy: 0.9995 - val_iou_metric: 0.9504 - lr: 1.2500e-05
# Epoch 48/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0015 - accuracy: 0.9982 - iou_metric: 0.9098
# Epoch 48: val_iou_metric did not improve from 0.95178
# 230/230 [==============================] - 18s 77ms/step - loss: 0.0015 - accuracy: 0.9982 - iou_metric: 0.9098 - val_loss: 2.1532e-04 - val_accuracy: 0.9995 - val_iou_metric: 0.9492 - lr: 1.2500e-05
# Epoch 49/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 0.9983 - iou_metric: 0.9124
# Epoch 49: val_iou_metric improved from 0.95178 to 0.95595, saving model to unet-3d.hdf5
# 230/230 [==============================] - 18s 80ms/step - loss: 0.0014 - accuracy: 0.9983 - iou_metric: 0.9124 - val_loss: 1.6858e-04 - val_accuracy: 0.9996 - val_iou_metric: 0.9559 - lr: 1.2500e-05
# Epoch 50/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 0.9983 - iou_metric: 0.9130
# Epoch 50: val_iou_metric did not improve from 0.95595
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0014 - accuracy: 0.9983 - iou_metric: 0.9130 - val_loss: 1.8411e-04 - val_accuracy: 0.9996 - val_iou_metric: 0.9525 - lr: 1.2500e-05

# %%
# Save model training history
np.save('unet-3d-history.npy',model_unet.history.history)

# %%
# Plot accuracy and loss 

## Accuracy
plt.plot(model_unet.history.history['accuracy'])
plt.plot(model_unet.history.history['val_accuracy'])
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper left')
plt.show()

## Loss
plt.plot(model_unet.history.history['loss'])
plt.plot(model_unet.history.history['val_loss'])
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper left')

# %% [markdown]
# ## Attention U-Net

# %%
# Train Attention U-Net with generator
model_attention_unet = UNetAM(input_size=(512, 512, 3), lr = 0.000055, filter_base=16)
save_model = ModelCheckpoint('unet-3d.hdf5', monitor='val_iou_metric',verbose=1, save_best_only=True, mode='max' )

train = trainGenerator(1, t_images, t_edges, t_masks, data_gen_args)

model_attention_unet.fit(
    train,
    steps_per_epoch=230,
    epochs=60,
    validation_data=([v_images, v_edges], v_masks),
    callbacks=[save_model, reduce_lr]
)
# Out:
# Epoch 1/60
# 230/230 [==============================] - ETA: 0s - loss: 0.3800 - accuracy: 0.9534 - iou_metric: 0.3521
# Epoch 1: val_iou_metric improved from -inf to 0.56752, saving model to unet-3d.hdf5
# 230/230 [==============================] - 20s 81ms/step - loss: 0.3800 - accuracy: 0.9534 - iou_metric: 0.3521 - val_loss: 0.0450 - val_accuracy: 0.9928 - val_iou_metric: 0.5675 - lr: 5.5000e-05
# Epoch 2/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0511 - accuracy: 0.9941 - iou_metric: 0.6100
# Epoch 2: val_iou_metric did not improve from 0.56752
# 230/230 [==============================] - 17s 76ms/step - loss: 0.0511 - accuracy: 0.9941 - iou_metric: 0.6100 - val_loss: 0.0765 - val_accuracy: 0.9877 - val_iou_metric: 0.4341 - lr: 5.5000e-05
# Epoch 3/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0391 - accuracy: 0.9949 - iou_metric: 0.6447
# Epoch 3: val_iou_metric improved from 0.56752 to 0.61031, saving model to unet-3d.hdf5
# 230/230 [==============================] - 17s 75ms/step - loss: 0.0391 - accuracy: 0.9949 - iou_metric: 0.6447 - val_loss: 0.0306 - val_accuracy: 0.9939 - val_iou_metric: 0.6103 - lr: 5.5000e-05
# Epoch 4/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0296 - accuracy: 0.9952 - iou_metric: 0.6787
# Epoch 4: val_iou_metric improved from 0.61031 to 0.66510, saving model to unet-3d.hdf5
# 230/230 [==============================] - 18s 77ms/step - loss: 0.0296 - accuracy: 0.9952 - iou_metric: 0.6787 - val_loss: 0.0236 - val_accuracy: 0.9952 - val_iou_metric: 0.6651 - lr: 5.5000e-05
# Epoch 5/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0251 - accuracy: 0.9955 - iou_metric: 0.6983
# Epoch 5: val_iou_metric improved from 0.66510 to 0.68817, saving model to unet-3d.hdf5
# 230/230 [==============================] - 17s 75ms/step - loss: 0.0251 - accuracy: 0.9955 - iou_metric: 0.6983 - val_loss: 0.0205 - val_accuracy: 0.9957 - val_iou_metric: 0.6882 - lr: 5.5000e-05
# Epoch 6/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0228 - accuracy: 0.9957 - iou_metric: 0.7074
# Epoch 6: val_iou_metric improved from 0.68817 to 0.71867, saving model to unet-3d.hdf5
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0228 - accuracy: 0.9957 - iou_metric: 0.7074 - val_loss: 0.0219 - val_accuracy: 0.9963 - val_iou_metric: 0.7187 - lr: 5.5000e-05
# Epoch 7/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0201 - accuracy: 0.9958 - iou_metric: 0.7234
# Epoch 7: val_iou_metric did not improve from 0.71867
# 230/230 [==============================] - 18s 77ms/step - loss: 0.0201 - accuracy: 0.9958 - iou_metric: 0.7234 - val_loss: 0.0176 - val_accuracy: 0.9950 - val_iou_metric: 0.6481 - lr: 5.5000e-05
# Epoch 8/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0194 - accuracy: 0.9958 - iou_metric: 0.7262
# Epoch 8: val_iou_metric improved from 0.71867 to 0.73883, saving model to unet-3d.hdf5
# 230/230 [==============================] - 18s 77ms/step - loss: 0.0194 - accuracy: 0.9958 - iou_metric: 0.7262 - val_loss: 0.0106 - val_accuracy: 0.9967 - val_iou_metric: 0.7388 - lr: 5.5000e-05
# Epoch 9/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0142 - accuracy: 0.9964 - iou_metric: 0.7579
# Epoch 9: val_iou_metric did not improve from 0.73883
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0142 - accuracy: 0.9964 - iou_metric: 0.7579 - val_loss: 0.0092 - val_accuracy: 0.9966 - val_iou_metric: 0.7320 - lr: 5.5000e-05
# Epoch 10/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0142 - accuracy: 0.9964 - iou_metric: 0.7637
# Epoch 10: val_iou_metric improved from 0.73883 to 0.78317, saving model to unet-3d.hdf5
# 230/230 [==============================] - 18s 77ms/step - loss: 0.0142 - accuracy: 0.9964 - iou_metric: 0.7637 - val_loss: 0.0070 - val_accuracy: 0.9974 - val_iou_metric: 0.7832 - lr: 5.5000e-05
# Epoch 11/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0149 - accuracy: 0.9963 - iou_metric: 0.7653
# Epoch 11: val_iou_metric did not improve from 0.78317
# 230/230 [==============================] - 18s 77ms/step - loss: 0.0149 - accuracy: 0.9963 - iou_metric: 0.7653 - val_loss: 0.0069 - val_accuracy: 0.9971 - val_iou_metric: 0.7667 - lr: 5.5000e-05
# Epoch 12/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0089 - accuracy: 0.9970 - iou_metric: 0.7989
# Epoch 12: val_iou_metric did not improve from 0.78317
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0089 - accuracy: 0.9970 - iou_metric: 0.7989 - val_loss: 0.0055 - val_accuracy: 0.9973 - val_iou_metric: 0.7826 - lr: 5.5000e-05
# Epoch 13/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0079 - accuracy: 0.9972 - iou_metric: 0.8104
# Epoch 13: val_iou_metric improved from 0.78317 to 0.79549, saving model to unet-3d.hdf5
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0079 - accuracy: 0.9972 - iou_metric: 0.8104 - val_loss: 0.0049 - val_accuracy: 0.9976 - val_iou_metric: 0.7955 - lr: 5.5000e-05
# Epoch 14/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0077 - accuracy: 0.9972 - iou_metric: 0.8128
# Epoch 14: val_iou_metric improved from 0.79549 to 0.82972, saving model to unet-3d.hdf5
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0077 - accuracy: 0.9972 - iou_metric: 0.8128 - val_loss: 0.0035 - val_accuracy: 0.9981 - val_iou_metric: 0.8297 - lr: 5.5000e-05
# Epoch 15/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0060 - accuracy: 0.9975 - iou_metric: 0.8301
# Epoch 15: val_iou_metric improved from 0.82972 to 0.83432, saving model to unet-3d.hdf5
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0060 - accuracy: 0.9975 - iou_metric: 0.8301 - val_loss: 0.0034 - val_accuracy: 0.9981 - val_iou_metric: 0.8343 - lr: 5.5000e-05
# Epoch 16/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0063 - accuracy: 0.9973 - iou_metric: 0.8238
# Epoch 16: val_iou_metric did not improve from 0.83432
# 230/230 [==============================] - 18s 77ms/step - loss: 0.0063 - accuracy: 0.9973 - iou_metric: 0.8238 - val_loss: 0.0090 - val_accuracy: 0.9965 - val_iou_metric: 0.7167 - lr: 5.5000e-05
# Epoch 17/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0091 - accuracy: 0.9972 - iou_metric: 0.8173
# Epoch 17: val_iou_metric did not improve from 0.83432
# 230/230 [==============================] - 18s 77ms/step - loss: 0.0091 - accuracy: 0.9972 - iou_metric: 0.8173 - val_loss: 0.0170 - val_accuracy: 0.9948 - val_iou_metric: 0.5978 - lr: 5.5000e-05
# Epoch 18/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0241 - accuracy: 0.9946 - iou_metric: 0.7674
# Epoch 18: val_iou_metric did not improve from 0.83432
# 230/230 [==============================] - 18s 77ms/step - loss: 0.0241 - accuracy: 0.9946 - iou_metric: 0.7674 - val_loss: 0.0045 - val_accuracy: 0.9978 - val_iou_metric: 0.8163 - lr: 5.5000e-05
# Epoch 19/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0057 - accuracy: 0.9974 - iou_metric: 0.8329
# Epoch 19: val_iou_metric did not improve from 0.83432
# 230/230 [==============================] - 18s 77ms/step - loss: 0.0057 - accuracy: 0.9974 - iou_metric: 0.8329 - val_loss: 0.0040 - val_accuracy: 0.9978 - val_iou_metric: 0.8167 - lr: 5.5000e-05
# Epoch 20/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0056 - accuracy: 0.9974 - iou_metric: 0.8381
# Epoch 20: val_iou_metric improved from 0.83432 to 0.84715, saving model to unet-3d.hdf5
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0056 - accuracy: 0.9974 - iou_metric: 0.8381 - val_loss: 0.0032 - val_accuracy: 0.9982 - val_iou_metric: 0.8472 - lr: 5.5000e-05
# Epoch 21/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0048 - accuracy: 0.9976 - iou_metric: 0.8443
# Epoch 21: val_iou_metric did not improve from 0.84715
# 230/230 [==============================] - 17s 76ms/step - loss: 0.0048 - accuracy: 0.9976 - iou_metric: 0.8443 - val_loss: 0.0028 - val_accuracy: 0.9982 - val_iou_metric: 0.8442 - lr: 5.5000e-05
# Epoch 22/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0061 - accuracy: 0.9974 - iou_metric: 0.8356
# Epoch 22: val_iou_metric improved from 0.84715 to 0.85845, saving model to unet-3d.hdf5
# 230/230 [==============================] - 17s 76ms/step - loss: 0.0061 - accuracy: 0.9974 - iou_metric: 0.8356 - val_loss: 0.0023 - val_accuracy: 0.9984 - val_iou_metric: 0.8585 - lr: 5.5000e-05
# Epoch 23/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0056 - accuracy: 0.9974 - iou_metric: 0.8422
# Epoch 23: val_iou_metric did not improve from 0.85845
# 230/230 [==============================] - 18s 76ms/step - loss: 0.0056 - accuracy: 0.9974 - iou_metric: 0.8422 - val_loss: 0.0031 - val_accuracy: 0.9983 - val_iou_metric: 0.8577 - lr: 5.5000e-05
# Epoch 24/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0062 - accuracy: 0.9972 - iou_metric: 0.8379
# Epoch 24: val_iou_metric did not improve from 0.85845
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0062 - accuracy: 0.9972 - iou_metric: 0.8379 - val_loss: 0.0046 - val_accuracy: 0.9977 - val_iou_metric: 0.8061 - lr: 5.5000e-05
# Epoch 25/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0052 - accuracy: 0.9976 - iou_metric: 0.8446
# Epoch 25: val_iou_metric improved from 0.85845 to 0.87098, saving model to unet-3d.hdf5
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0052 - accuracy: 0.9976 - iou_metric: 0.8446 - val_loss: 0.0019 - val_accuracy: 0.9985 - val_iou_metric: 0.8710 - lr: 5.5000e-05
# Epoch 26/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0037 - accuracy: 0.9978 - iou_metric: 0.8609
# Epoch 26: val_iou_metric did not improve from 0.87098
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0037 - accuracy: 0.9978 - iou_metric: 0.8609 - val_loss: 0.0022 - val_accuracy: 0.9984 - val_iou_metric: 0.8632 - lr: 5.5000e-05
# Epoch 27/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0037 - accuracy: 0.9977 - iou_metric: 0.8614
# Epoch 27: val_iou_metric improved from 0.87098 to 0.90139, saving model to unet-3d.hdf5
# 230/230 [==============================] - 17s 76ms/step - loss: 0.0037 - accuracy: 0.9977 - iou_metric: 0.8614 - val_loss: 0.0013 - val_accuracy: 0.9989 - val_iou_metric: 0.9014 - lr: 5.5000e-05
# Epoch 28/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0032 - accuracy: 0.9979 - iou_metric: 0.8683
# Epoch 28: val_iou_metric did not improve from 0.90139
# 230/230 [==============================] - 17s 75ms/step - loss: 0.0032 - accuracy: 0.9979 - iou_metric: 0.8683 - val_loss: 0.0013 - val_accuracy: 0.9989 - val_iou_metric: 0.8960 - lr: 5.5000e-05
# Epoch 29/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0034 - accuracy: 0.9979 - iou_metric: 0.8700
# Epoch 29: val_iou_metric did not improve from 0.90139
# 230/230 [==============================] - 17s 76ms/step - loss: 0.0034 - accuracy: 0.9979 - iou_metric: 0.8700 - val_loss: 0.0013 - val_accuracy: 0.9988 - val_iou_metric: 0.8887 - lr: 5.5000e-05
# Epoch 30/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0036 - accuracy: 0.9978 - iou_metric: 0.8654
# Epoch 30: val_iou_metric did not improve from 0.90139
# 230/230 [==============================] - 18s 76ms/step - loss: 0.0036 - accuracy: 0.9978 - iou_metric: 0.8654 - val_loss: 0.0013 - val_accuracy: 0.9988 - val_iou_metric: 0.8911 - lr: 5.5000e-05
# Epoch 31/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0034 - accuracy: 0.9978 - iou_metric: 0.8696
# Epoch 31: val_iou_metric improved from 0.90139 to 0.91230, saving model to unet-3d.hdf5
# 230/230 [==============================] - 17s 75ms/step - loss: 0.0034 - accuracy: 0.9978 - iou_metric: 0.8696 - val_loss: 9.2128e-04 - val_accuracy: 0.9991 - val_iou_metric: 0.9123 - lr: 5.5000e-05
# Epoch 32/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0030 - accuracy: 0.9979 - iou_metric: 0.8749
# Epoch 32: val_iou_metric improved from 0.91230 to 0.91273, saving model to unet-3d.hdf5
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0030 - accuracy: 0.9979 - iou_metric: 0.8749 - val_loss: 8.9530e-04 - val_accuracy: 0.9991 - val_iou_metric: 0.9127 - lr: 5.5000e-05
# Epoch 33/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0030 - accuracy: 0.9979 - iou_metric: 0.8736
# Epoch 33: val_iou_metric did not improve from 0.91273
# 230/230 [==============================] - 17s 76ms/step - loss: 0.0030 - accuracy: 0.9979 - iou_metric: 0.8736 - val_loss: 9.6105e-04 - val_accuracy: 0.9990 - val_iou_metric: 0.9037 - lr: 5.5000e-05
# Epoch 34/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0028 - accuracy: 0.9980 - iou_metric: 0.8770
# Epoch 34: val_iou_metric did not improve from 0.91273
# 230/230 [==============================] - 17s 76ms/step - loss: 0.0028 - accuracy: 0.9980 - iou_metric: 0.8770 - val_loss: 0.0013 - val_accuracy: 0.9988 - val_iou_metric: 0.8904 - lr: 5.5000e-05
# Epoch 35/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0027 - accuracy: 0.9980 - iou_metric: 0.8805
# Epoch 35: val_iou_metric improved from 0.91273 to 0.91756, saving model to unet-3d.hdf5
# 230/230 [==============================] - 18s 76ms/step - loss: 0.0027 - accuracy: 0.9980 - iou_metric: 0.8805 - val_loss: 7.7729e-04 - val_accuracy: 0.9991 - val_iou_metric: 0.9176 - lr: 5.5000e-05
# Epoch 36/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0047 - accuracy: 0.9978 - iou_metric: 0.8766
# Epoch 36: val_iou_metric did not improve from 0.91756
# 230/230 [==============================] - 18s 77ms/step - loss: 0.0047 - accuracy: 0.9978 - iou_metric: 0.8766 - val_loss: 0.0034 - val_accuracy: 0.9982 - val_iou_metric: 0.8443 - lr: 5.5000e-05
# Epoch 37/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0053 - accuracy: 0.9974 - iou_metric: 0.8481
# Epoch 37: val_iou_metric did not improve from 0.91756
# 230/230 [==============================] - 17s 76ms/step - loss: 0.0053 - accuracy: 0.9974 - iou_metric: 0.8481 - val_loss: 0.0011 - val_accuracy: 0.9990 - val_iou_metric: 0.9049 - lr: 5.5000e-05
# Epoch 38/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0032 - accuracy: 0.9978 - iou_metric: 0.8699
# Epoch 38: val_iou_metric did not improve from 0.91756
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0032 - accuracy: 0.9978 - iou_metric: 0.8699 - val_loss: 0.0010 - val_accuracy: 0.9990 - val_iou_metric: 0.9084 - lr: 5.5000e-05
# Epoch 39/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0041 - accuracy: 0.9977 - iou_metric: 0.8659
# Epoch 39: val_iou_metric did not improve from 0.91756
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0041 - accuracy: 0.9977 - iou_metric: 0.8659 - val_loss: 0.0014 - val_accuracy: 0.9987 - val_iou_metric: 0.8850 - lr: 5.5000e-05
# Epoch 40/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0027 - accuracy: 0.9979 - iou_metric: 0.8797
# Epoch 40: val_iou_metric did not improve from 0.91756
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0027 - accuracy: 0.9979 - iou_metric: 0.8797 - val_loss: 8.8462e-04 - val_accuracy: 0.9990 - val_iou_metric: 0.9109 - lr: 5.5000e-05
# Epoch 41/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0026 - accuracy: 0.9980 - iou_metric: 0.8844
# Epoch 41: val_iou_metric improved from 0.91756 to 0.91912, saving model to unet-3d.hdf5
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0026 - accuracy: 0.9980 - iou_metric: 0.8844 - val_loss: 6.5697e-04 - val_accuracy: 0.9992 - val_iou_metric: 0.9191 - lr: 5.5000e-05
# Epoch 42/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0027 - accuracy: 0.9980 - iou_metric: 0.8823
# Epoch 42: val_iou_metric did not improve from 0.91912
# 230/230 [==============================] - 17s 73ms/step - loss: 0.0027 - accuracy: 0.9980 - iou_metric: 0.8823 - val_loss: 8.4268e-04 - val_accuracy: 0.9990 - val_iou_metric: 0.9111 - lr: 5.5000e-05
# Epoch 43/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0026 - accuracy: 0.9980 - iou_metric: 0.8855
# Epoch 43: val_iou_metric improved from 0.91912 to 0.92042, saving model to unet-3d.hdf5
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0026 - accuracy: 0.9980 - iou_metric: 0.8855 - val_loss: 6.2245e-04 - val_accuracy: 0.9992 - val_iou_metric: 0.9204 - lr: 5.5000e-05
# Epoch 44/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0023 - accuracy: 0.9981 - iou_metric: 0.8895
# Epoch 44: val_iou_metric improved from 0.92042 to 0.93354, saving model to unet-3d.hdf5
# 230/230 [==============================] - 18s 77ms/step - loss: 0.0023 - accuracy: 0.9981 - iou_metric: 0.8895 - val_loss: 5.2098e-04 - val_accuracy: 0.9993 - val_iou_metric: 0.9335 - lr: 5.5000e-05
# Epoch 45/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0021 - accuracy: 0.9981 - iou_metric: 0.8920
# Epoch 45: val_iou_metric did not improve from 0.93354
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0021 - accuracy: 0.9981 - iou_metric: 0.8920 - val_loss: 5.1602e-04 - val_accuracy: 0.9993 - val_iou_metric: 0.9322 - lr: 5.5000e-05
# Epoch 46/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0021 - accuracy: 0.9981 - iou_metric: 0.8936
# Epoch 46: val_iou_metric did not improve from 0.93354
# 230/230 [==============================] - 17s 75ms/step - loss: 0.0021 - accuracy: 0.9981 - iou_metric: 0.8936 - val_loss: 4.7602e-04 - val_accuracy: 0.9993 - val_iou_metric: 0.9329 - lr: 5.5000e-05
# Epoch 47/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0022 - accuracy: 0.9981 - iou_metric: 0.8917
# Epoch 47: val_iou_metric did not improve from 0.93354
# 230/230 [==============================] - 17s 76ms/step - loss: 0.0022 - accuracy: 0.9981 - iou_metric: 0.8917 - val_loss: 5.0789e-04 - val_accuracy: 0.9993 - val_iou_metric: 0.9315 - lr: 5.5000e-05
# Epoch 48/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0021 - accuracy: 0.9981 - iou_metric: 0.8942
# Epoch 48: val_iou_metric did not improve from 0.93354
# 230/230 [==============================] - 18s 77ms/step - loss: 0.0021 - accuracy: 0.9981 - iou_metric: 0.8942 - val_loss: 5.4776e-04 - val_accuracy: 0.9993 - val_iou_metric: 0.9314 - lr: 5.5000e-05
# Epoch 49/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 0.9981 - iou_metric: 0.8964
# Epoch 49: val_iou_metric did not improve from 0.93354
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0019 - accuracy: 0.9981 - iou_metric: 0.8964 - val_loss: 4.4635e-04 - val_accuracy: 0.9993 - val_iou_metric: 0.9316 - lr: 5.5000e-05
# Epoch 50/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 0.9981 - iou_metric: 0.8976
# Epoch 50: val_iou_metric improved from 0.93354 to 0.93524, saving model to unet-3d.hdf5
# 230/230 [==============================] - 17s 76ms/step - loss: 0.0019 - accuracy: 0.9981 - iou_metric: 0.8976 - val_loss: 4.1463e-04 - val_accuracy: 0.9993 - val_iou_metric: 0.9352 - lr: 5.5000e-05
# Epoch 51/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 0.9982 - iou_metric: 0.8991
# Epoch 51: val_iou_metric did not improve from 0.93524
# 230/230 [==============================] - 17s 75ms/step - loss: 0.0019 - accuracy: 0.9982 - iou_metric: 0.8991 - val_loss: 4.3703e-04 - val_accuracy: 0.9993 - val_iou_metric: 0.9348 - lr: 5.5000e-05
# Epoch 52/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 0.9981 - iou_metric: 0.8993
# Epoch 52: val_iou_metric improved from 0.93524 to 0.93773, saving model to unet-3d.hdf5
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0018 - accuracy: 0.9981 - iou_metric: 0.8993 - val_loss: 3.9637e-04 - val_accuracy: 0.9994 - val_iou_metric: 0.9377 - lr: 5.5000e-05
# Epoch 53/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 0.9982 - iou_metric: 0.9014
# Epoch 53: val_iou_metric improved from 0.93773 to 0.94141, saving model to unet-3d.hdf5
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0018 - accuracy: 0.9982 - iou_metric: 0.9014 - val_loss: 3.4172e-04 - val_accuracy: 0.9994 - val_iou_metric: 0.9414 - lr: 5.5000e-05
# Epoch 54/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 0.9982 - iou_metric: 0.8994
# Epoch 54: val_iou_metric did not improve from 0.94141
# 230/230 [==============================] - 18s 77ms/step - loss: 0.0018 - accuracy: 0.9982 - iou_metric: 0.8994 - val_loss: 4.4274e-04 - val_accuracy: 0.9993 - val_iou_metric: 0.9314 - lr: 5.5000e-05
# Epoch 55/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0017 - accuracy: 0.9982 - iou_metric: 0.9029
# Epoch 55: val_iou_metric improved from 0.94141 to 0.94359, saving model to unet-3d.hdf5
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0017 - accuracy: 0.9982 - iou_metric: 0.9029 - val_loss: 3.3059e-04 - val_accuracy: 0.9994 - val_iou_metric: 0.9436 - lr: 5.5000e-05
# Epoch 56/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0017 - accuracy: 0.9982 - iou_metric: 0.9028
# Epoch 56: val_iou_metric improved from 0.94359 to 0.94503, saving model to unet-3d.hdf5
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0017 - accuracy: 0.9982 - iou_metric: 0.9028 - val_loss: 2.9625e-04 - val_accuracy: 0.9994 - val_iou_metric: 0.9450 - lr: 5.5000e-05
# Epoch 57/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0038 - accuracy: 0.9980 - iou_metric: 0.8853
# Epoch 57: val_iou_metric did not improve from 0.94503
# 230/230 [==============================] - 18s 77ms/step - loss: 0.0038 - accuracy: 0.9980 - iou_metric: 0.8853 - val_loss: 0.0064 - val_accuracy: 0.9986 - val_iou_metric: 0.8801 - lr: 5.5000e-05
# Epoch 58/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0054 - accuracy: 0.9976 - iou_metric: 0.8649
# Epoch 58: val_iou_metric did not improve from 0.94503
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0054 - accuracy: 0.9976 - iou_metric: 0.8649 - val_loss: 6.3505e-04 - val_accuracy: 0.9992 - val_iou_metric: 0.9223 - lr: 5.5000e-05
# Epoch 59/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0020 - accuracy: 0.9981 - iou_metric: 0.8960
# Epoch 59: val_iou_metric did not improve from 0.94503
# 230/230 [==============================] - 18s 77ms/step - loss: 0.0020 - accuracy: 0.9981 - iou_metric: 0.8960 - val_loss: 6.3914e-04 - val_accuracy: 0.9992 - val_iou_metric: 0.9291 - lr: 5.5000e-05
# Epoch 60/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 0.9982 - iou_metric: 0.9004
# Epoch 60: val_iou_metric did not improve from 0.94503
# 230/230 [==============================] - 18s 77ms/step - loss: 0.0018 - accuracy: 0.9982 - iou_metric: 0.9004 - val_loss: 4.8887e-04 - val_accuracy: 0.9993 - val_iou_metric: 0.9333 - lr: 5.5000e-05

# %%
# Save model history
np.save('unet-attention-3d-history.npy',model_attention_unet.history.history)

# %% [markdown]
# # Import Models and Compute Metrics

# %% [markdown]
# ## RGB

# %%
# Load 3-dim models and history stats
attention_unet = load_model(
    'unet-attention-3d.hdf5',
    custom_objects={
        'iou_metric': iou_metric,
        'focal_tversky_loss': focal_tversky_loss
    }
)

unet = load_model(
    'unet-3d.hdf5',
    custom_objects={'iou_metric': iou_metric,
                    'focal_tversky_loss': focal_tversky_loss
                   }
)

unet_history = np.load('unet-3d-history.npy', allow_pickle='TRUE').item()
attention_unet_history = np.load('unet-attention-3d-history.npy', allow_pickle='TRUE').item()

# %%
# Plot accuracy and loss for U-Net

## Accuracy

plt.plot(unet_history['iou_metric'])
plt.plot(unet_history['val_iou_metric'])

plt.ylabel('IoU')
plt.xlabel('Epoch')
plt.legend(['Unet Training IoU', 'Unet Validation IoU'], loc='upper left')
plt.grid(True)
plt.show()


## Loss
plt.plot(unet_history['loss'])
plt.plot(unet_history['val_loss'])
plt.ylabel('Loss', size=12)
plt.xlabel('Epoch', size=12)
plt.legend(['Unet Training Loss', 'Unet Validation Loss'], loc='lower right')

# %%
# Plot accuracy and loss for Attention U-Net

## Accuracy

plt.plot(attention_unet_history['iou_metric'])
plt.plot(attention_unet_history['val_iou_metric'])

plt.ylabel('IoU')
plt.xlabel('Epoch')
plt.legend(['Attention Unet Training IoU', 'Attention Unet Validation IoU'], loc='upper left')
plt.grid(True)
plt.show()


## Loss
plt.plot(attention_unet_history['loss'])
plt.plot(attention_unet_history['val_loss'])
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Attention Unet Training Loss', 'Attention Unet Validation Loss'], loc='upper right')

# %%
def model_predict(model, image, edge=None):
    if len(model.inputs) == 2:
        return model.predict([image, edge])
    else:
        return model.predict(image)
def score_eval(model, images, masks, edges=None):
    scores = []

    num_inputs = len(model.inputs)

    for i in range(len(images)):
        img = images[i].reshape(1, 512, 512, 3)

        if num_inputs == 1:
            pred = model.predict(img)

        elif num_inputs == 2:
            edg = edges[i].reshape(1, 512, 512, 1)
            pred = model.predict([img, edg])

        pred = np.round(pred).flatten()
        true = masks[i].flatten()

        scores.append(accuracy_score(true, pred))

    return scores

def recall_eval(model, images, masks, edges):
    recalls = []

    for i in range(len(images)):
        pred = model_predict(model,
                             images[i].reshape(1,512,512,3),
                             edges[i].reshape(1,512,512,1))[0]

        pred = np.round(pred).flatten()
        gt = masks[i].flatten()

        recalls.append(recall_score(gt, pred, average='binary', zero_division=0))

    return recalls
def precision_eval(model, images, masks, edges=None):
    precision = []

    for i in range(len(images)):
        img = images[i].reshape(1,512,512,3)

        if edges is not None:
            ed = edges[i].reshape(1,512,512,1)
        else:
            ed = None

        pred = model_predict(model, img, ed)[0]
        pred = np.round(pred).flatten()

        precision.append(precision_score(masks[i].flatten(), pred, average='weighted'))

    return precision


def f1_score_eval(model, images, masks, edges):
    prec = np.mean(precision_eval(model, images, masks, edges))
    rec  = np.mean(recall_eval(model, images, masks, edges))

    if prec + rec == 0:
        return 0
    return 2 * prec * rec / (prec + rec)

def produce_mask(image): # Outputs rounded image (binary)
  return np.round(image)

# %%
unet_score = score_eval(unet, validation_images, validation_masks, edges=validation_edges)
am_unet_score = score_eval(attention_unet, validation_images, validation_masks, edges=validation_edges)
# Out:
# 1/1 [==============================] - 0s 379ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 310ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 32ms/step

# %%
# Precision and recall of each model
unet_precision = (precision_eval(unet, validation_images, validation_masks, edges=validation_edges))
am_unet_precision = (precision_eval(attention_unet, validation_images, validation_masks, edges=validation_edges))

unet_recall = (recall_eval(unet, validation_images, validation_masks, edges=validation_edges))
am_unet_recall = (recall_eval(attention_unet, validation_images, validation_masks, edges=validation_edges))
# Out:
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step

# %%
# F1-scores of each model
unet_f1_score = (f1_score_eval(unet, validation_images, validation_masks, edges=validation_edges))
am_unet_f1_score = (f1_score_eval(attention_unet, validation_images, validation_masks, edges=validation_edges))
# Out:
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step

# %%
# Print score eval results for each model
print('U-Net accuracy: ', np.mean(unet_score), np.std(unet_score))
print('Attention U-Net accuracy: ', np.mean(am_unet_score), np.std(am_unet_score))

# %%
# Print precision eval results for each model
print('U-Net precision: ', np.mean(unet_precision), np.std(unet_precision))
print('Attention U-Net precision: ', np.mean(am_unet_precision), np.std(am_unet_precision))

# %%
# Print recall eval results for each model
print('U-Net recall: ', np.mean(unet_recall), np.std(unet_recall))
print('Attention U-Net recall: ', np.mean(am_unet_recall), np.std(am_unet_recall))

# %%
# Print f1-score eval results for each model
print('U-Net F1-score: ', np.mean(unet_f1_score))
print('Attention U-Net F1-score: ', np.mean(am_unet_f1_score))
