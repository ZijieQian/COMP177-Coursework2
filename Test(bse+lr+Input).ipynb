# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import pandas as pd
import PIL
from PIL import Image
import pathlib
import os
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.losses import *
import requests
# !pip install pyunpack patool
import pyunpack
import matplotlib.pyplot as plt
from tensorflow.keras import backend as K
from tensorflow.keras.callbacks import ModelCheckpoint
import sys
from tensorflow.keras.optimizers import Adam
# !pip install rarfile segmentation-models git+https://github.com/davej23/image-segmentation-keras.git rioxarray
from rarfile import RarFile
import segmentation_models as sm
from keras.applications import vgg16
from sklearn.metrics import *
import rioxarray as rxr
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import cv2
import PIL.Image
import math
# Out:
# 2025-12-11 19:59:43.057416: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-12-11 19:59:43.222471: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-11 19:59:43.258751: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-12-11 19:59:43.905449: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2025-12-11 19:59:43.905513: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2025-12-11 19:59:43.905518: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# Segmentation Models: using `keras` framework.

# %% [markdown]
# # Functions

# %%
def get_edge_from_mask(mask):
    # mask: (512,512,1) uint8 or int → return (512,512,1) float32
    m = (mask.squeeze() > 0).astype(np.uint8)
    kernel = np.ones((3,3), np.uint8)
    edge = cv2.morphologyEx(m, cv2.MORPH_GRADIENT, kernel)
    edge = edge.astype(np.float32)
    return edge.reshape(512,512,1)
def iou_metric(y_true, y_pred, smooth=1e-6):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred > 0.5, tf.float32)  # 二值化

    intersection = tf.reduce_sum(y_true * y_pred)
    union = tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) - intersection

    return (intersection + smooth) / (union + smooth)

# %% [markdown]
# # Ingest and Process New Dataset

# %%
base_dir = r"./Nepal landslide dataset/"

# %%
# Ingest images

training_images_list = os.listdir(r"{}Training/image/".format(base_dir))
training_masks_list = []
training_images = []

for n in training_images_list:
    im = PIL.Image.open(r"{}Training/image/{}".format(base_dir, n))
    training_images.append(im)
    # Nepal uses .tiff → label uses .png
    training_masks_list.append(n[:-5] + '.png')
    
# Training masks
training_masks = []
for n in training_masks_list:
    im = PIL.Image.open(r"{}Training/label/{}".format(base_dir, n))
    training_masks.append(im)

# -------------------------
# Test images
# -------------------------
test_images_list = os.listdir(r"{}Test/image/".format(base_dir))
test_images = []

for n in test_images_list:
    im = PIL.Image.open(r"{}Test/image/{}".format(base_dir, n))
    test_images.append(im)

# -------------------------
# Validation images
# -------------------------
validation_images_list = os.listdir(r"{}Validation/images/".format(base_dir))
validation_masks_list = []
validation_images = []

for n in validation_images_list:
    im = PIL.Image.open(r"{}Validation/images/{}".format(base_dir, n))
    validation_images.append(im)
    validation_masks_list.append(n[:-5] + '.png')

# Validation masks
validation_masks = []
for n in validation_masks_list:
    im = PIL.Image.open(r"{}Validation/masks/{}".format(base_dir, n))
    validation_masks.append(im)

# %%
# Pre-process (same as original, only ensure resize)
# -------------------------

# images (3-channel)
for i in range(len(training_images)):
    arr = np.array(training_images[i]) / 255
    arr = cv2.resize(arr, (512, 512))     
    arr = arr.reshape(1, 512, 512, 3)
    training_images[i] = arr.astype('float32')

# masks (1-channel)
for i in range(len(training_masks)):
    arr = np.array(training_masks[i])
    arr = cv2.resize(arr, (512, 512))    
    arr = arr.reshape(1, 512, 512, 1)
    training_masks[i] = arr.astype('int')

training_edges = []
for i in range(len(training_masks)):
    mask = training_masks[i].astype(np.uint8)
    edge = get_edge_from_mask(mask)
    training_edges.append(edge)

# # validation images
for i in range(len(validation_images)):
    arr = np.array(validation_images[i]) / 255
    arr = cv2.resize(arr, (512, 512))
    arr = arr.reshape(1, 512, 512, 3)
    validation_images[i] = arr.astype('float32')

# validation masks
for i in range(len(validation_masks)):
    arr = np.array(validation_masks[i])
    arr = cv2.resize(arr, (512, 512))
    arr = arr.reshape(1, 512, 512, 1)
    validation_masks[i] = arr.astype('int')

validation_edges = []
                          
for i in range(len(validation_masks)):
    mask = validation_masks[i].astype(np.uint8)
    edge = get_edge_from_mask(mask)
    validation_edges.append(edge)

# test images
for i in range(len(test_images)):
    arr = np.array(test_images[i]) / 255
    arr = cv2.resize(arr, (512, 512))
    arr = arr.reshape(1, 512, 512, 3)
    test_images[i] = arr.astype('float32')

# %%
validation_Nepal_landslide_dataset = tf.data.Dataset.from_tensor_slices((validation_images, validation_masks))
# Out:
# 2025-12-10 20:43:19.758088: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-12-10 20:43:20.353435: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1616] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22168 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:d6:00.0, compute capability: 8.6

# %%
# Data loader/generator from: https://github.com/bragagnololu/UNet-defmapping.git
#

def adjustData(img, mask, num_class):
  
    mask[mask > 0.3] = 1 # FOREST
    mask[mask <= 0.3] = 0 # NON-FOREST

    return (img,mask)

def trainGenerator(batch_size, images, edges, masks, aug_dict):
    data_gen = ImageDataGenerator(**aug_dict)

    img_gen  = data_gen.flow(images, batch_size=batch_size, seed=1)
    edge_gen = data_gen.flow(edges,  batch_size=batch_size, seed=1)
    mask_gen = data_gen.flow(masks,  batch_size=batch_size, seed=1)

    while True:
        batch_img  = img_gen.next()
        batch_edge = edge_gen.next()
        batch_mask = mask_gen.next()

        yield ([batch_img, batch_edge], batch_mask)

# %%
t_images = np.stack(training_images)
t_masks = np.stack(training_masks)
t_images = np.squeeze(t_images, axis=1)
t_edges = np.stack(training_edges)
t_masks  = np.squeeze(t_masks, axis=1)


v_edges = np.stack(validation_edges)
v_images = np.stack(validation_images)
v_masks = np.stack(validation_masks)
v_images = np.squeeze(v_images, axis=1)
v_masks  = np.squeeze(v_masks, axis=1)


data_gen_args = dict(
    rotation_range=10,
    width_shift_range=0.05,
    height_shift_range=0.05,
    zoom_range=0.05,
    horizontal_flip=True,
    vertical_flip=True,
    fill_mode='reflect',
)

train = trainGenerator(1, t_images, t_edges, t_masks, data_gen_args)

# %%
BETA = 0.95
SMOOTH_TERM = 1e-7

def dice_coef(y_true, y_pred, smooth=SMOOTH_TERM):
    y_true_float = K.cast(y_true, 'float32') 
    
    y_true_f = K.flatten(y_true_float)
    y_pred_f = K.flatten(y_pred)
    
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def dice_loss(y_true, y_pred):
    return 1 - dice_coef(y_true, y_pred)

def weighted_bce_loss(y_true, y_pred, beta=BETA):

    y_true_float = K.cast(y_true, 'float32') 


    bce = K.binary_crossentropy(y_true_float, y_pred)
    

    weight = beta * y_true_float + (1.0 - beta) * (1.0 - y_true_float)
    

    weighted_bce = weight * bce
    return K.mean(weighted_bce)

def bce_dice_loss_weighted(y_true, y_pred):

    wbce = weighted_bce_loss(y_true, y_pred)
    

    dice = dice_loss(y_true, y_pred)
    

    return 0.5*wbce + 0.5*dice

    
# def focal_tversky_loss(y_true, y_pred, alpha=0.7, beta=0.3, gamma=2.0):
#     y_true = K.cast(y_true, 'float32')
#     y_pred = K.cast(y_pred, 'float32')


#     TP = K.sum(y_true * y_pred)
#     FP = K.sum((1 - y_true) * y_pred)
#     FN = K.sum(y_true * (1 - y_pred))

#     tversky = (TP + 1e-7) / (TP + alpha*FN + beta*FP + 1e-7)
#     focal_tversky = K.pow((1 - tversky), gamma)

#     return focal_tversky

# import numpy as np

# def mask_stats(masks):
#     # masks: numpy array (N,H,W,1) or list
#     a = np.array(masks)
#     if a.ndim==4 and a.shape[-1]==1:
#         a = a[...,0]
#     flat = a.flatten()
#     unique, counts = np.unique(flat, return_counts=True)
#     freq = dict(zip(unique.tolist(), counts.tolist()))
#     total = flat.size
#     print("unique values & counts:", freq)
#     print("total pixels:", total)
#     for k,v in freq.items():
#         print(f"value {k}: {v} pixels, ratio {v/total:.6f}")
#     return freq

# mask_stats(t_masks)   # 把你训练集的 mask 数组代入
# mask_stats(validation_masks)

# %%
from tensorflow.keras.callbacks import Callback
from tensorflow.keras.callbacks import ReduceLROnPlateau

reduce_lr = ReduceLROnPlateau(
    monitor='val_iou_metric',  
    mode='max',              
    factor=0.5,
    patience=7,
    verbose=1,
    min_lr=1e-7
)

# %% [markdown]
# # Models

# %% [markdown]
# ## U-Net

# %%
'''
  Convolutional block with set parameters and activation layer after
'''

def convBlock(input, filters, kernel, kernel_init='he_normal', act='relu', transpose=False):
  if transpose == False:
    #conv = ZeroPadding2D((1,1))(input)
    conv = Conv2D(filters, kernel, padding = 'same', kernel_initializer = kernel_init)(input)
  else:
    #conv = ZeroPadding2D((1,1))(input)
    conv = Conv2DTranspose(filters, kernel, padding = 'same', kernel_initializer = kernel_init)(input)

  conv = Activation(act)(conv)
  return conv
  
'''
  U-Net model
'''

def UNet(trained_weights = None, input_size = (512,512,3), drop_rate = 0.25, lr=0.0001):

    ## Can add pretrained weights by specifying 'trained_weights'

    # Input layer
    input_img = Input((512,512,3))
    input_edge = Input((512,512,1))
    inputs = Concatenate(axis=-1)([input_img, input_edge])

    ## Contraction phase
    conv1 = convBlock(inputs, 64, 3)
    conv1 = convBlock(conv1, 64, 3)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = convBlock(pool1, 128, 3)
    conv2 = convBlock(conv2, 128, 3)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    #drop2 = Dropout(drop_rate)(pool2)

    conv3 = convBlock(pool2, 256, 3)
    conv3 = convBlock(conv3, 256, 3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    #drop3 = Dropout(drop_rate)(pool3)

    conv4 = convBlock(pool3, 512, 3)
    conv4 = convBlock(conv4, 512, 3)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)
    #drop4 = Dropout(drop_rate)(pool4)

    conv5 = convBlock(pool4, 1024, 3)
    conv5 = convBlock(conv5, 1024, 3)

    ## Expansion phase
    up6 = (Conv2DTranspose(512, kernel_size=2, strides=2, kernel_initializer='he_normal')(conv5))
    merge6 = concatenate([conv4,up6])
    conv6 = convBlock(merge6, 512, 3)
    conv6 = convBlock(conv6, 512, 3)
    #conv6 = Dropout(drop_rate)(conv6)

    up7 = (Conv2DTranspose(256, kernel_size=2, strides=2, kernel_initializer='he_normal')(conv6))
    merge7 = concatenate([conv3,up7])
    conv7 = convBlock(merge7, 256, 3)
    conv7 = convBlock(conv7, 256, 3)
    #conv7 = Dropout(drop_rate)(conv7)

    up8 = (Conv2DTranspose(128, kernel_size=2, strides=2, kernel_initializer='he_normal')(conv7))
    merge8 = concatenate([conv2,up8])
    conv8 = convBlock(merge8, 128, 3)
    conv8 = convBlock(conv8, 128, 3)
    #conv8 = Dropout(drop_rate)(conv8)

    up9 = (Conv2DTranspose(64, kernel_size=2, strides=2, kernel_initializer='he_normal')(conv8))
    merge9 = concatenate([conv1,up9])
    conv9 = convBlock(merge9, 64, 3)
    conv9 = convBlock(conv9, 64, 3)

    # Output layer
    conv10 = convBlock(conv9, 1, 1, act='sigmoid')

    model = Model([input_img, input_edge], conv10)

    # model.compile(optimizer = Adam(learning_rate = lr), loss = 'binary_crossentropy', metrics = ['accuracy', 'mse'])
    model.compile(optimizer = Adam(learning_rate = lr), loss = bce_dice_loss_weighted, metrics = ['accuracy', iou_metric])
    if trained_weights != None:
    	model.load_weights(trained_weights)

    return model

# %%
# Print model layers and number of parameters
UNet().summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 512, 512, 3  0           []
#                                 )]
#
#  input_4 (InputLayer)           [(None, 512, 512, 1  0           []
#                                 )]
#
#  concatenate_5 (Concatenate)    (None, 512, 512, 4)  0           ['input_3[0][0]',
#                                                                   'input_4[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 512, 512, 64  2368        ['concatenate_5[0][0]']
#                                 )
#
#  activation_19 (Activation)     (None, 512, 512, 64  0           ['conv2d_19[0][0]']
#                                 )
#
#  conv2d_20 (Conv2D)             (None, 512, 512, 64  36928       ['activation_19[0][0]']
#                                 )
#
#  activation_20 (Activation)     (None, 512, 512, 64  0           ['conv2d_20[0][0]']
#                                 )
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 256, 256, 64  0          ['activation_20[0][0]']
#                                 )
#
#  conv2d_21 (Conv2D)             (None, 256, 256, 12  73856       ['max_pooling2d_4[0][0]']
#                                 8)
#
#  activation_21 (Activation)     (None, 256, 256, 12  0           ['conv2d_21[0][0]']
#                                 8)
#
#  conv2d_22 (Conv2D)             (None, 256, 256, 12  147584      ['activation_21[0][0]']
#                                 8)
#
#  activation_22 (Activation)     (None, 256, 256, 12  0           ['conv2d_22[0][0]']
#                                 8)
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 128, 128, 12  0          ['activation_22[0][0]']
#                                 8)
#
#  conv2d_23 (Conv2D)             (None, 128, 128, 25  295168      ['max_pooling2d_5[0][0]']
#                                 6)
#
#  activation_23 (Activation)     (None, 128, 128, 25  0           ['conv2d_23[0][0]']
#                                 6)
#
#  conv2d_24 (Conv2D)             (None, 128, 128, 25  590080      ['activation_23[0][0]']
#                                 6)
#
#  activation_24 (Activation)     (None, 128, 128, 25  0           ['conv2d_24[0][0]']
#                                 6)
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 64, 64, 256)  0          ['activation_24[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 64, 64, 512)  1180160     ['max_pooling2d_6[0][0]']
#
#  activation_25 (Activation)     (None, 64, 64, 512)  0           ['conv2d_25[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 64, 64, 512)  2359808     ['activation_25[0][0]']
#
#  activation_26 (Activation)     (None, 64, 64, 512)  0           ['conv2d_26[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 32, 32, 512)  0          ['activation_26[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 32, 32, 1024  4719616     ['max_pooling2d_7[0][0]']
#                                 )
#
#  activation_27 (Activation)     (None, 32, 32, 1024  0           ['conv2d_27[0][0]']
#                                 )
#
#  conv2d_28 (Conv2D)             (None, 32, 32, 1024  9438208     ['activation_27[0][0]']
#                                 )
#
#  activation_28 (Activation)     (None, 32, 32, 1024  0           ['conv2d_28[0][0]']
#                                 )
#
#  conv2d_transpose_4 (Conv2DTran  (None, 64, 64, 512)  2097664    ['activation_28[0][0]']
#  spose)
#
#  concatenate_6 (Concatenate)    (None, 64, 64, 1024  0           ['activation_26[0][0]',
#                                 )                                 'conv2d_transpose_4[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 64, 64, 512)  4719104     ['concatenate_6[0][0]']
#
#  activation_29 (Activation)     (None, 64, 64, 512)  0           ['conv2d_29[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 64, 64, 512)  2359808     ['activation_29[0][0]']
#
#  activation_30 (Activation)     (None, 64, 64, 512)  0           ['conv2d_30[0][0]']
#
#  conv2d_transpose_5 (Conv2DTran  (None, 128, 128, 25  524544     ['activation_30[0][0]']
#  spose)                         6)
#
#  concatenate_7 (Concatenate)    (None, 128, 128, 51  0           ['activation_24[0][0]',
#                                 2)                                'conv2d_transpose_5[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 128, 128, 25  1179904     ['concatenate_7[0][0]']
#                                 6)
#
#  activation_31 (Activation)     (None, 128, 128, 25  0           ['conv2d_31[0][0]']
#                                 6)
#
#  conv2d_32 (Conv2D)             (None, 128, 128, 25  590080      ['activation_31[0][0]']
#                                 6)
#
#  activation_32 (Activation)     (None, 128, 128, 25  0           ['conv2d_32[0][0]']
#                                 6)
#
#  conv2d_transpose_6 (Conv2DTran  (None, 256, 256, 12  131200     ['activation_32[0][0]']
#  spose)                         8)
#
#  concatenate_8 (Concatenate)    (None, 256, 256, 25  0           ['activation_22[0][0]',
#                                 6)                                'conv2d_transpose_6[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 256, 256, 12  295040      ['concatenate_8[0][0]']
#                                 8)
#
#  activation_33 (Activation)     (None, 256, 256, 12  0           ['conv2d_33[0][0]']
#                                 8)
#
#  conv2d_34 (Conv2D)             (None, 256, 256, 12  147584      ['activation_33[0][0]']
#                                 8)
#
#  activation_34 (Activation)     (None, 256, 256, 12  0           ['conv2d_34[0][0]']
#                                 8)
#
#  conv2d_transpose_7 (Conv2DTran  (None, 512, 512, 64  32832      ['activation_34[0][0]']
#  spose)                         )
#
#  concatenate_9 (Concatenate)    (None, 512, 512, 12  0           ['activation_20[0][0]',
#                                 8)                                'conv2d_transpose_7[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 512, 512, 64  73792       ['concatenate_9[0][0]']
#                                 )
#
#  activation_35 (Activation)     (None, 512, 512, 64  0           ['conv2d_35[0][0]']
#                                 )
#
#  conv2d_36 (Conv2D)             (None, 512, 512, 64  36928       ['activation_35[0][0]']
#                                 )
#
#  activation_36 (Activation)     (None, 512, 512, 64  0           ['conv2d_36[0][0]']
#                                 )
#
#  conv2d_37 (Conv2D)             (None, 512, 512, 1)  65          ['activation_36[0][0]']
#
#  activation_37 (Activation)     (None, 512, 512, 1)  0           ['conv2d_37[0][0]']
#
# ==================================================================================================
# Total params: 31,032,321
# Trainable params: 31,032,321
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## Attention U-Net

# %%
'''
  Convolutional block with two conv layers and two activation layers
'''

def convBlock2(input, filters, kernel, kernel_init='he_normal', act='relu', transpose=False):
  if transpose == False:
    conv = Conv2D(filters, kernel, padding = 'same', kernel_initializer = kernel_init)(input)
    conv = Activation(act)(conv)
    conv = Conv2D(filters, kernel, padding = 'same', kernel_initializer = kernel_init)(conv)
    conv = Activation(act)(conv)
  else:
    conv = Conv2DTranspose(filters, kernel, padding = 'same', kernel_initializer = kernel_init)(input)
    conv = Activation(act)(conv)
    conv = Conv2DTranspose(filters, kernel, padding = 'same', kernel_initializer = kernel_init)(conv)
    conv = Activation(act)(conv)

  return conv
  
'''
  Attention block/mechanism
'''
def attention_block(x, gating, inter_shape, drop_rate=0.25):
   
    # Find shape of inputs
    shape_x = K.int_shape(x)
    shape_g = K.int_shape(gating)

    ## Process x vector and gating signal
    # x vector input and processing
    theta_x = Conv2D(inter_shape, (2, 2), strides=(2, 2), padding='same')(x)
    phi_g = Conv2D(inter_shape, (1, 1), padding='same')(gating)

    # match spatial size
    upsample_g = UpSampling2D(size=(theta_x.shape[1] // phi_g.shape[1],
                                    theta_x.shape[2] // phi_g.shape[2]), 
                              interpolation='bilinear')(phi_g)

    concat_xg = add([upsample_g, theta_x])
    act_xg = Activation('relu')(concat_xg)

    psi = Conv2D(1, (1, 1), padding='same')(act_xg)
    psi = Activation('sigmoid')(psi)

    # upsample attention mask to match x
    psi_up = UpSampling2D(size=(x.shape[1] // psi.shape[1],
                                x.shape[2] // psi.shape[2]), 
                          interpolation='bilinear')(psi)

    # apply attention
    y = multiply([x, psi_up])
    return y


'''
  Attention U-Net model
'''

def UNetAM(trained_weights = None, input_size = (512,512,3), drop_rate = 0.25, lr=0.0001, filter_base=16):

    ## Can add pretrained weights by specifying 'trained_weights'

    # Input layer
    input_img = Input((512,512,3))
    input_edge = Input((512,512,1))
    inputs = Concatenate(axis=-1)([input_img, input_edge])


    ## Contraction phase
    conv = convBlock2(inputs, filter_base, 3)
    #conv0 = Dropout(drop_rate)(conv0)

    conv0 = MaxPooling2D(pool_size=(2, 2))(conv)
    conv0 = convBlock2(conv0, 2 * filter_base, 3)

    pool0 = MaxPooling2D(pool_size=(2, 2))(conv0)
    conv1 = convBlock2(pool0, 4 * filter_base, 3)
    #conv1 = Dropout(drop_rate)(conv1)

    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    conv2 = convBlock2(pool1, 8 * filter_base, 3)
    #conv2 = Dropout(drop_rate)(conv2)

    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    conv3 = convBlock2(pool2, 16 * filter_base, 3)
    #conv3 = Dropout(drop_rate)(conv3)

    ## Expansion phase
    up4 = (Conv2DTranspose(8 * filter_base, kernel_size=2, strides=2, kernel_initializer='he_normal')(conv3))
    merge4 = attention_block(conv2, conv3, 8 * filter_base, drop_rate) # Attention gate
    conv4 = concatenate([up4, merge4])
    conv4 = convBlock2(conv4, 8 * filter_base, 3)

    up5 = (Conv2DTranspose(4 * filter_base, kernel_size=2, strides=2, kernel_initializer='he_normal')(conv4))
    merge5 = attention_block(conv1, conv4, 4 * filter_base, drop_rate) # Attention gate
    conv5 = concatenate([up5, merge5])
    conv5 = convBlock2(conv5, 4 * filter_base, 3)

    up6 = (Conv2DTranspose(2 * filter_base, kernel_size=2, strides=2, kernel_initializer='he_normal')(conv5))
    merge6 = attention_block(conv0, conv5, 2 * filter_base, drop_rate) # Attention gate
    conv6 = concatenate([up6, merge6])
    conv6 = convBlock2(conv6, 2 * filter_base, 3)

    up7 = (Conv2DTranspose(1 * filter_base, kernel_size=2, strides=2, kernel_initializer='he_normal')(conv6))
    merge7 = attention_block(conv, conv6, 1 * filter_base, drop_rate)
    conv7 = concatenate([up7, merge7]) 
    conv7 = convBlock2(conv7, 1 * filter_base, 3)

    ## Output layer
    out = convBlock(conv7, 1, 1, act='sigmoid')

    model = Model([input_img, input_edge], out)

    # model.compile(optimizer = Adam(learning_rate = lr), loss = 'binary_crossentropy', metrics = ['accuracy', 'mse'])
    model.compile(optimizer = Adam(learning_rate = lr), loss = bce_dice_loss_weighted, metrics = ['accuracy', iou_metric])
    if trained_weights != None:
    	model.load_weights(trained_weights)

    return model

# %%
# Print model layers and number of parameters
UNetAM().summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_5 (InputLayer)           [(None, 512, 512, 3  0           []
#                                 )]
#
#  input_6 (InputLayer)           [(None, 512, 512, 1  0           []
#                                 )]
#
#  concatenate_10 (Concatenate)   (None, 512, 512, 4)  0           ['input_5[0][0]',
#                                                                   'input_6[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 512, 512, 16  592         ['concatenate_10[0][0]']
#                                 )
#
#  activation_38 (Activation)     (None, 512, 512, 16  0           ['conv2d_38[0][0]']
#                                 )
#
#  conv2d_39 (Conv2D)             (None, 512, 512, 16  2320        ['activation_38[0][0]']
#                                 )
#
#  activation_39 (Activation)     (None, 512, 512, 16  0           ['conv2d_39[0][0]']
#                                 )
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 256, 256, 16  0          ['activation_39[0][0]']
#                                 )
#
#  conv2d_40 (Conv2D)             (None, 256, 256, 32  4640        ['max_pooling2d_8[0][0]']
#                                 )
#
#  activation_40 (Activation)     (None, 256, 256, 32  0           ['conv2d_40[0][0]']
#                                 )
#
#  conv2d_41 (Conv2D)             (None, 256, 256, 32  9248        ['activation_40[0][0]']
#                                 )
#
#  activation_41 (Activation)     (None, 256, 256, 32  0           ['conv2d_41[0][0]']
#                                 )
#
#  max_pooling2d_9 (MaxPooling2D)  (None, 128, 128, 32  0          ['activation_41[0][0]']
#                                 )
#
#  conv2d_42 (Conv2D)             (None, 128, 128, 64  18496       ['max_pooling2d_9[0][0]']
#                                 )
#
#  activation_42 (Activation)     (None, 128, 128, 64  0           ['conv2d_42[0][0]']
#                                 )
#
#  conv2d_43 (Conv2D)             (None, 128, 128, 64  36928       ['activation_42[0][0]']
#                                 )
#
#  activation_43 (Activation)     (None, 128, 128, 64  0           ['conv2d_43[0][0]']
#                                 )
#
#  max_pooling2d_10 (MaxPooling2D  (None, 64, 64, 64)  0           ['activation_43[0][0]']
#  )
#
#  conv2d_44 (Conv2D)             (None, 64, 64, 128)  73856       ['max_pooling2d_10[0][0]']
#
#  activation_44 (Activation)     (None, 64, 64, 128)  0           ['conv2d_44[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 64, 64, 128)  147584      ['activation_44[0][0]']
#
#  activation_45 (Activation)     (None, 64, 64, 128)  0           ['conv2d_45[0][0]']
#
#  max_pooling2d_11 (MaxPooling2D  (None, 32, 32, 128)  0          ['activation_45[0][0]']
#  )
#
#  conv2d_46 (Conv2D)             (None, 32, 32, 256)  295168      ['max_pooling2d_11[0][0]']
#
#  activation_46 (Activation)     (None, 32, 32, 256)  0           ['conv2d_46[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 32, 32, 256)  590080      ['activation_46[0][0]']
#
#  activation_47 (Activation)     (None, 32, 32, 256)  0           ['conv2d_47[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 32, 32, 128)  32896       ['activation_47[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 32, 32, 128)  0           ['conv2d_49[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 32, 32, 128)  65664       ['activation_45[0][0]']
#
#  add (Add)                      (None, 32, 32, 128)  0           ['up_sampling2d[0][0]',
#                                                                   'conv2d_48[0][0]']
#
#  activation_48 (Activation)     (None, 32, 32, 128)  0           ['add[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 32, 32, 1)    129         ['activation_48[0][0]']
#
#  activation_49 (Activation)     (None, 32, 32, 1)    0           ['conv2d_50[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 64, 64, 1)   0           ['activation_49[0][0]']
#
#  conv2d_transpose_8 (Conv2DTran  (None, 64, 64, 128)  131200     ['activation_47[0][0]']
#  spose)
#
#  multiply (Multiply)            (None, 64, 64, 128)  0           ['activation_45[0][0]',
#                                                                   'up_sampling2d_1[0][0]']
#
#  concatenate_11 (Concatenate)   (None, 64, 64, 256)  0           ['conv2d_transpose_8[0][0]',
#                                                                   'multiply[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 64, 64, 128)  295040      ['concatenate_11[0][0]']
#
#  activation_50 (Activation)     (None, 64, 64, 128)  0           ['conv2d_51[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 64, 64, 128)  147584      ['activation_50[0][0]']
#
#  activation_51 (Activation)     (None, 64, 64, 128)  0           ['conv2d_52[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 64, 64, 64)   8256        ['activation_51[0][0]']
#
#  up_sampling2d_2 (UpSampling2D)  (None, 64, 64, 64)  0           ['conv2d_54[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 64, 64, 64)   16448       ['activation_43[0][0]']
#
#  add_1 (Add)                    (None, 64, 64, 64)   0           ['up_sampling2d_2[0][0]',
#                                                                   'conv2d_53[0][0]']
#
#  activation_52 (Activation)     (None, 64, 64, 64)   0           ['add_1[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 64, 64, 1)    65          ['activation_52[0][0]']
#
#  activation_53 (Activation)     (None, 64, 64, 1)    0           ['conv2d_55[0][0]']
#
#  up_sampling2d_3 (UpSampling2D)  (None, 128, 128, 1)  0          ['activation_53[0][0]']
#
#  conv2d_transpose_9 (Conv2DTran  (None, 128, 128, 64  32832      ['activation_51[0][0]']
#  spose)                         )
#
#  multiply_1 (Multiply)          (None, 128, 128, 64  0           ['activation_43[0][0]',
#                                 )                                 'up_sampling2d_3[0][0]']
#
#  concatenate_12 (Concatenate)   (None, 128, 128, 12  0           ['conv2d_transpose_9[0][0]',
#                                 8)                                'multiply_1[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 128, 128, 64  73792       ['concatenate_12[0][0]']
#                                 )
#
#  activation_54 (Activation)     (None, 128, 128, 64  0           ['conv2d_56[0][0]']
#                                 )
#
#  conv2d_57 (Conv2D)             (None, 128, 128, 64  36928       ['activation_54[0][0]']
#                                 )
#
#  activation_55 (Activation)     (None, 128, 128, 64  0           ['conv2d_57[0][0]']
#                                 )
#
#  conv2d_59 (Conv2D)             (None, 128, 128, 32  2080        ['activation_55[0][0]']
#                                 )
#
#  up_sampling2d_4 (UpSampling2D)  (None, 128, 128, 32  0          ['conv2d_59[0][0]']
#                                 )
#
#  conv2d_58 (Conv2D)             (None, 128, 128, 32  4128        ['activation_41[0][0]']
#                                 )
#
#  add_2 (Add)                    (None, 128, 128, 32  0           ['up_sampling2d_4[0][0]',
#                                 )                                 'conv2d_58[0][0]']
#
#  activation_56 (Activation)     (None, 128, 128, 32  0           ['add_2[0][0]']
#                                 )
#
#  conv2d_60 (Conv2D)             (None, 128, 128, 1)  33          ['activation_56[0][0]']
#
#  activation_57 (Activation)     (None, 128, 128, 1)  0           ['conv2d_60[0][0]']
#
#  up_sampling2d_5 (UpSampling2D)  (None, 256, 256, 1)  0          ['activation_57[0][0]']
#
#  conv2d_transpose_10 (Conv2DTra  (None, 256, 256, 32  8224       ['activation_55[0][0]']
#  nspose)                        )
#
#  multiply_2 (Multiply)          (None, 256, 256, 32  0           ['activation_41[0][0]',
#                                 )                                 'up_sampling2d_5[0][0]']
#
#  concatenate_13 (Concatenate)   (None, 256, 256, 64  0           ['conv2d_transpose_10[0][0]',
#                                 )                                 'multiply_2[0][0]']
#
#  conv2d_61 (Conv2D)             (None, 256, 256, 32  18464       ['concatenate_13[0][0]']
#                                 )
#
#  activation_58 (Activation)     (None, 256, 256, 32  0           ['conv2d_61[0][0]']
#                                 )
#
#  conv2d_62 (Conv2D)             (None, 256, 256, 32  9248        ['activation_58[0][0]']
#                                 )
#
#  activation_59 (Activation)     (None, 256, 256, 32  0           ['conv2d_62[0][0]']
#                                 )
#
#  conv2d_64 (Conv2D)             (None, 256, 256, 16  528         ['activation_59[0][0]']
#                                 )
#
#  up_sampling2d_6 (UpSampling2D)  (None, 256, 256, 16  0          ['conv2d_64[0][0]']
#                                 )
#
#  conv2d_63 (Conv2D)             (None, 256, 256, 16  1040        ['activation_39[0][0]']
#                                 )
#
#  add_3 (Add)                    (None, 256, 256, 16  0           ['up_sampling2d_6[0][0]',
#                                 )                                 'conv2d_63[0][0]']
#
#  activation_60 (Activation)     (None, 256, 256, 16  0           ['add_3[0][0]']
#                                 )
#
#  conv2d_65 (Conv2D)             (None, 256, 256, 1)  17          ['activation_60[0][0]']
#
#  activation_61 (Activation)     (None, 256, 256, 1)  0           ['conv2d_65[0][0]']
#
#  up_sampling2d_7 (UpSampling2D)  (None, 512, 512, 1)  0          ['activation_61[0][0]']
#
#  conv2d_transpose_11 (Conv2DTra  (None, 512, 512, 16  2064       ['activation_59[0][0]']
#  nspose)                        )
#
#  multiply_3 (Multiply)          (None, 512, 512, 16  0           ['activation_39[0][0]',
#                                 )                                 'up_sampling2d_7[0][0]']
#
#  concatenate_14 (Concatenate)   (None, 512, 512, 32  0           ['conv2d_transpose_11[0][0]',
#                                 )                                 'multiply_3[0][0]']
#
#  conv2d_66 (Conv2D)             (None, 512, 512, 16  4624        ['concatenate_14[0][0]']
#                                 )
#
#  activation_62 (Activation)     (None, 512, 512, 16  0           ['conv2d_66[0][0]']
#                                 )
#
#  conv2d_67 (Conv2D)             (None, 512, 512, 16  2320        ['activation_62[0][0]']
#                                 )
#
#  activation_63 (Activation)     (None, 512, 512, 16  0           ['conv2d_67[0][0]']
#                                 )
#
#  conv2d_68 (Conv2D)             (None, 512, 512, 1)  17          ['activation_63[0][0]']
#
#  activation_64 (Activation)     (None, 512, 512, 1)  0           ['conv2d_68[0][0]']
#
# ==================================================================================================
# Total params: 2,072,533
# Trainable params: 2,072,533
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# # Train on New feature data

# %%
# Train U-Net with generator
model_unet = UNet(lr=0.000025)
save_model = ModelCheckpoint('unet-3d.hdf5', monitor='val_iou_metric',verbose=1, save_best_only=True, mode='max')


train = trainGenerator(1, t_images, t_edges, t_masks, data_gen_args)
model_unet.fit(
    train,
    steps_per_epoch=230,
    epochs=50,
    validation_data=([v_images, v_edges], v_masks),
    callbacks=[save_model, reduce_lr]
)
# Out:
# Epoch 1/50
# 2025-12-10 20:45:28.361557: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8101
# 2025-12-10 20:45:31.129134: I tensorflow/stream_executor/cuda/cuda_blas.cc:1614] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 230/230 [==============================] - ETA: 0s - loss: 0.2728 - accuracy: 0.9872 - iou_metric: 0.4066
# Epoch 1: val_iou_metric improved from -inf to 0.69012, saving model to unet-3d.hdf5
# 230/230 [==============================] - 49s 171ms/step - loss: 0.2728 - accuracy: 0.9872 - iou_metric: 0.4066 - val_loss: 0.1087 - val_accuracy: 0.9959 - val_iou_metric: 0.6901 - lr: 2.5000e-05
# Epoch 2/50
# 230/230 [==============================] - ETA: 0s - loss: 0.1010 - accuracy: 0.9957 - iou_metric: 0.7110
# Epoch 2: val_iou_metric improved from 0.69012 to 0.74041, saving model to unet-3d.hdf5
# 230/230 [==============================] - 18s 79ms/step - loss: 0.1010 - accuracy: 0.9957 - iou_metric: 0.7110 - val_loss: 0.0906 - val_accuracy: 0.9968 - val_iou_metric: 0.7404 - lr: 2.5000e-05
# Epoch 3/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0789 - accuracy: 0.9965 - iou_metric: 0.7656
# Epoch 3: val_iou_metric improved from 0.74041 to 0.82192, saving model to unet-3d.hdf5
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0789 - accuracy: 0.9965 - iou_metric: 0.7656 - val_loss: 0.0488 - val_accuracy: 0.9980 - val_iou_metric: 0.8219 - lr: 2.5000e-05
# Epoch 4/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0584 - accuracy: 0.9973 - iou_metric: 0.8190
# Epoch 4: val_iou_metric improved from 0.82192 to 0.85555, saving model to unet-3d.hdf5
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0584 - accuracy: 0.9973 - iou_metric: 0.8190 - val_loss: 0.0364 - val_accuracy: 0.9985 - val_iou_metric: 0.8555 - lr: 2.5000e-05
# Epoch 5/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0613 - accuracy: 0.9970 - iou_metric: 0.8187
# Epoch 5: val_iou_metric improved from 0.85555 to 0.87448, saving model to unet-3d.hdf5
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0613 - accuracy: 0.9970 - iou_metric: 0.8187 - val_loss: 0.0357 - val_accuracy: 0.9986 - val_iou_metric: 0.8745 - lr: 2.5000e-05
# Epoch 6/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0428 - accuracy: 0.9976 - iou_metric: 0.8588
# Epoch 6: val_iou_metric improved from 0.87448 to 0.89071, saving model to unet-3d.hdf5
# 230/230 [==============================] - 18s 80ms/step - loss: 0.0428 - accuracy: 0.9976 - iou_metric: 0.8588 - val_loss: 0.0291 - val_accuracy: 0.9989 - val_iou_metric: 0.8907 - lr: 2.5000e-05
# Epoch 7/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0404 - accuracy: 0.9978 - iou_metric: 0.8657
# Epoch 7: val_iou_metric did not improve from 0.89071
# 230/230 [==============================] - 18s 77ms/step - loss: 0.0404 - accuracy: 0.9978 - iou_metric: 0.8657 - val_loss: 0.0352 - val_accuracy: 0.9986 - val_iou_metric: 0.8663 - lr: 2.5000e-05
# Epoch 8/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0368 - accuracy: 0.9978 - iou_metric: 0.8758
# Epoch 8: val_iou_metric improved from 0.89071 to 0.92168, saving model to unet-3d.hdf5
# 230/230 [==============================] - 18s 80ms/step - loss: 0.0368 - accuracy: 0.9978 - iou_metric: 0.8758 - val_loss: 0.0199 - val_accuracy: 0.9992 - val_iou_metric: 0.9217 - lr: 2.5000e-05
# Epoch 9/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0319 - accuracy: 0.9980 - iou_metric: 0.8896
# Epoch 9: val_iou_metric improved from 0.92168 to 0.92788, saving model to unet-3d.hdf5
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0319 - accuracy: 0.9980 - iou_metric: 0.8896 - val_loss: 0.0175 - val_accuracy: 0.9993 - val_iou_metric: 0.9279 - lr: 2.5000e-05
# Epoch 10/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0299 - accuracy: 0.9981 - iou_metric: 0.8968
# Epoch 10: val_iou_metric improved from 0.92788 to 0.92862, saving model to unet-3d.hdf5
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0299 - accuracy: 0.9981 - iou_metric: 0.8968 - val_loss: 0.0174 - val_accuracy: 0.9993 - val_iou_metric: 0.9286 - lr: 2.5000e-05
# Epoch 11/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0277 - accuracy: 0.9981 - iou_metric: 0.9026
# Epoch 11: val_iou_metric improved from 0.92862 to 0.94340, saving model to unet-3d.hdf5
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0277 - accuracy: 0.9981 - iou_metric: 0.9026 - val_loss: 0.0145 - val_accuracy: 0.9994 - val_iou_metric: 0.9434 - lr: 2.5000e-05
# Epoch 12/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0285 - accuracy: 0.9981 - iou_metric: 0.9018
# Epoch 12: val_iou_metric improved from 0.94340 to 0.94652, saving model to unet-3d.hdf5
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0285 - accuracy: 0.9981 - iou_metric: 0.9018 - val_loss: 0.0130 - val_accuracy: 0.9995 - val_iou_metric: 0.9465 - lr: 2.5000e-05
# Epoch 13/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0274 - accuracy: 0.9982 - iou_metric: 0.9042
# Epoch 13: val_iou_metric did not improve from 0.94652
# 230/230 [==============================] - 17s 75ms/step - loss: 0.0274 - accuracy: 0.9982 - iou_metric: 0.9042 - val_loss: 0.0133 - val_accuracy: 0.9995 - val_iou_metric: 0.9448 - lr: 2.5000e-05
# Epoch 14/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0285 - accuracy: 0.9981 - iou_metric: 0.9009
# Epoch 14: val_iou_metric did not improve from 0.94652
# 230/230 [==============================] - 17s 73ms/step - loss: 0.0285 - accuracy: 0.9981 - iou_metric: 0.9009 - val_loss: 0.0128 - val_accuracy: 0.9995 - val_iou_metric: 0.9464 - lr: 2.5000e-05
# Epoch 15/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0256 - accuracy: 0.9982 - iou_metric: 0.9103
# Epoch 15: val_iou_metric did not improve from 0.94652
# 230/230 [==============================] - 17s 74ms/step - loss: 0.0256 - accuracy: 0.9982 - iou_metric: 0.9103 - val_loss: 0.0144 - val_accuracy: 0.9994 - val_iou_metric: 0.9335 - lr: 2.5000e-05
# Epoch 16/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0226 - accuracy: 0.9983 - iou_metric: 0.9196
# Epoch 16: val_iou_metric improved from 0.94652 to 0.96329, saving model to unet-3d.hdf5
# 230/230 [==============================] - 18s 77ms/step - loss: 0.0226 - accuracy: 0.9983 - iou_metric: 0.9196 - val_loss: 0.0093 - val_accuracy: 0.9997 - val_iou_metric: 0.9633 - lr: 2.5000e-05
# Epoch 17/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0230 - accuracy: 0.9982 - iou_metric: 0.9187
# Epoch 17: val_iou_metric did not improve from 0.96329
# 230/230 [==============================] - 18s 76ms/step - loss: 0.0230 - accuracy: 0.9982 - iou_metric: 0.9187 - val_loss: 0.0093 - val_accuracy: 0.9996 - val_iou_metric: 0.9580 - lr: 2.5000e-05
# Epoch 18/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0233 - accuracy: 0.9983 - iou_metric: 0.9169
# Epoch 18: val_iou_metric improved from 0.96329 to 0.96435, saving model to unet-3d.hdf5
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0233 - accuracy: 0.9983 - iou_metric: 0.9169 - val_loss: 0.0086 - val_accuracy: 0.9997 - val_iou_metric: 0.9644 - lr: 2.5000e-05
# Epoch 19/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0215 - accuracy: 0.9983 - iou_metric: 0.9230
# Epoch 19: val_iou_metric improved from 0.96435 to 0.96888, saving model to unet-3d.hdf5
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0215 - accuracy: 0.9983 - iou_metric: 0.9230 - val_loss: 0.0078 - val_accuracy: 0.9997 - val_iou_metric: 0.9689 - lr: 2.5000e-05
# Epoch 20/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0206 - accuracy: 0.9983 - iou_metric: 0.9256
# Epoch 20: val_iou_metric improved from 0.96888 to 0.97105, saving model to unet-3d.hdf5
# 230/230 [==============================] - 18s 80ms/step - loss: 0.0206 - accuracy: 0.9983 - iou_metric: 0.9256 - val_loss: 0.0076 - val_accuracy: 0.9997 - val_iou_metric: 0.9710 - lr: 2.5000e-05
# Epoch 21/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0204 - accuracy: 0.9984 - iou_metric: 0.9263
# Epoch 21: val_iou_metric did not improve from 0.97105
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0204 - accuracy: 0.9984 - iou_metric: 0.9263 - val_loss: 0.0072 - val_accuracy: 0.9997 - val_iou_metric: 0.9692 - lr: 2.5000e-05
# Epoch 22/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0202 - accuracy: 0.9984 - iou_metric: 0.9273
# Epoch 22: val_iou_metric improved from 0.97105 to 0.97203, saving model to unet-3d.hdf5
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0202 - accuracy: 0.9984 - iou_metric: 0.9273 - val_loss: 0.0067 - val_accuracy: 0.9997 - val_iou_metric: 0.9720 - lr: 2.5000e-05
# Epoch 23/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0295 - accuracy: 0.9980 - iou_metric: 0.9017
# Epoch 23: val_iou_metric improved from 0.97203 to 0.97237, saving model to unet-3d.hdf5
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0295 - accuracy: 0.9980 - iou_metric: 0.9017 - val_loss: 0.0075 - val_accuracy: 0.9997 - val_iou_metric: 0.9724 - lr: 2.5000e-05
# Epoch 24/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0239 - accuracy: 0.9980 - iou_metric: 0.9189
# Epoch 24: val_iou_metric did not improve from 0.97237
# 230/230 [==============================] - 17s 75ms/step - loss: 0.0239 - accuracy: 0.9980 - iou_metric: 0.9189 - val_loss: 0.0151 - val_accuracy: 0.9995 - val_iou_metric: 0.9572 - lr: 2.5000e-05
# Epoch 25/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0228 - accuracy: 0.9982 - iou_metric: 0.9212
# Epoch 25: val_iou_metric improved from 0.97237 to 0.97359, saving model to unet-3d.hdf5
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0228 - accuracy: 0.9982 - iou_metric: 0.9212 - val_loss: 0.0069 - val_accuracy: 0.9997 - val_iou_metric: 0.9736 - lr: 2.5000e-05
# Epoch 26/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0197 - accuracy: 0.9984 - iou_metric: 0.9288
# Epoch 26: val_iou_metric improved from 0.97359 to 0.97468, saving model to unet-3d.hdf5
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0197 - accuracy: 0.9984 - iou_metric: 0.9288 - val_loss: 0.0061 - val_accuracy: 0.9998 - val_iou_metric: 0.9747 - lr: 2.5000e-05
# Epoch 27/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0195 - accuracy: 0.9984 - iou_metric: 0.9294
# Epoch 27: val_iou_metric improved from 0.97468 to 0.97728, saving model to unet-3d.hdf5
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0195 - accuracy: 0.9984 - iou_metric: 0.9294 - val_loss: 0.0056 - val_accuracy: 0.9998 - val_iou_metric: 0.9773 - lr: 2.5000e-05
# Epoch 28/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0215 - accuracy: 0.9983 - iou_metric: 0.9235
# Epoch 28: val_iou_metric did not improve from 0.97728
# 230/230 [==============================] - 18s 76ms/step - loss: 0.0215 - accuracy: 0.9983 - iou_metric: 0.9235 - val_loss: 0.0080 - val_accuracy: 0.9997 - val_iou_metric: 0.9727 - lr: 2.5000e-05
# Epoch 29/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0195 - accuracy: 0.9984 - iou_metric: 0.9294
# Epoch 29: val_iou_metric improved from 0.97728 to 0.97910, saving model to unet-3d.hdf5
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0195 - accuracy: 0.9984 - iou_metric: 0.9294 - val_loss: 0.0051 - val_accuracy: 0.9998 - val_iou_metric: 0.9791 - lr: 2.5000e-05
# Epoch 30/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0188 - accuracy: 0.9984 - iou_metric: 0.9318
# Epoch 30: val_iou_metric improved from 0.97910 to 0.98003, saving model to unet-3d.hdf5
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0188 - accuracy: 0.9984 - iou_metric: 0.9318 - val_loss: 0.0050 - val_accuracy: 0.9998 - val_iou_metric: 0.9800 - lr: 2.5000e-05
# Epoch 31/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0203 - accuracy: 0.9983 - iou_metric: 0.9278
# Epoch 31: val_iou_metric did not improve from 0.98003
# 230/230 [==============================] - 17s 75ms/step - loss: 0.0203 - accuracy: 0.9983 - iou_metric: 0.9278 - val_loss: 0.0066 - val_accuracy: 0.9997 - val_iou_metric: 0.9729 - lr: 2.5000e-05
# Epoch 32/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0191 - accuracy: 0.9984 - iou_metric: 0.9310
# Epoch 32: val_iou_metric did not improve from 0.98003
# 230/230 [==============================] - 17s 75ms/step - loss: 0.0191 - accuracy: 0.9984 - iou_metric: 0.9310 - val_loss: 0.0048 - val_accuracy: 0.9998 - val_iou_metric: 0.9797 - lr: 2.5000e-05
# Epoch 33/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0192 - accuracy: 0.9984 - iou_metric: 0.9303
# Epoch 33: val_iou_metric improved from 0.98003 to 0.98075, saving model to unet-3d.hdf5
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0192 - accuracy: 0.9984 - iou_metric: 0.9303 - val_loss: 0.0047 - val_accuracy: 0.9998 - val_iou_metric: 0.9808 - lr: 2.5000e-05
# Epoch 34/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0199 - accuracy: 0.9983 - iou_metric: 0.9285
# Epoch 34: val_iou_metric did not improve from 0.98075
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0199 - accuracy: 0.9983 - iou_metric: 0.9285 - val_loss: 0.0046 - val_accuracy: 0.9998 - val_iou_metric: 0.9804 - lr: 2.5000e-05
# Epoch 35/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0185 - accuracy: 0.9984 - iou_metric: 0.9327
# Epoch 35: val_iou_metric improved from 0.98075 to 0.98137, saving model to unet-3d.hdf5
# 230/230 [==============================] - 18s 80ms/step - loss: 0.0185 - accuracy: 0.9984 - iou_metric: 0.9327 - val_loss: 0.0043 - val_accuracy: 0.9998 - val_iou_metric: 0.9814 - lr: 2.5000e-05
# Epoch 36/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0184 - accuracy: 0.9984 - iou_metric: 0.9330
# Epoch 36: val_iou_metric did not improve from 0.98137
# 230/230 [==============================] - 17s 74ms/step - loss: 0.0184 - accuracy: 0.9984 - iou_metric: 0.9330 - val_loss: 0.0043 - val_accuracy: 0.9998 - val_iou_metric: 0.9808 - lr: 2.5000e-05
# Epoch 37/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0230 - accuracy: 0.9981 - iou_metric: 0.9212
# Epoch 37: val_iou_metric did not improve from 0.98137
# 230/230 [==============================] - 17s 75ms/step - loss: 0.0230 - accuracy: 0.9981 - iou_metric: 0.9212 - val_loss: 0.0106 - val_accuracy: 0.9996 - val_iou_metric: 0.9669 - lr: 2.5000e-05
# Epoch 38/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0231 - accuracy: 0.9982 - iou_metric: 0.9217
# Epoch 38: val_iou_metric did not improve from 0.98137
# 230/230 [==============================] - 17s 73ms/step - loss: 0.0231 - accuracy: 0.9982 - iou_metric: 0.9217 - val_loss: 0.0043 - val_accuracy: 0.9998 - val_iou_metric: 0.9809 - lr: 2.5000e-05
# Epoch 39/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0188 - accuracy: 0.9984 - iou_metric: 0.9315
# Epoch 39: val_iou_metric improved from 0.98137 to 0.98251, saving model to unet-3d.hdf5
# 230/230 [==============================] - 18s 77ms/step - loss: 0.0188 - accuracy: 0.9984 - iou_metric: 0.9315 - val_loss: 0.0041 - val_accuracy: 0.9998 - val_iou_metric: 0.9825 - lr: 2.5000e-05
# Epoch 40/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0182 - accuracy: 0.9984 - iou_metric: 0.9338
# Epoch 40: val_iou_metric improved from 0.98251 to 0.98276, saving model to unet-3d.hdf5
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0182 - accuracy: 0.9984 - iou_metric: 0.9338 - val_loss: 0.0038 - val_accuracy: 0.9999 - val_iou_metric: 0.9828 - lr: 2.5000e-05
# Epoch 41/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0184 - accuracy: 0.9984 - iou_metric: 0.9333
# Epoch 41: val_iou_metric did not improve from 0.98276
# 230/230 [==============================] - 17s 73ms/step - loss: 0.0184 - accuracy: 0.9984 - iou_metric: 0.9333 - val_loss: 0.0038 - val_accuracy: 0.9999 - val_iou_metric: 0.9826 - lr: 2.5000e-05
# Epoch 42/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0184 - accuracy: 0.9984 - iou_metric: 0.9329
# Epoch 42: val_iou_metric improved from 0.98276 to 0.98307, saving model to unet-3d.hdf5
# 230/230 [==============================] - 18s 77ms/step - loss: 0.0184 - accuracy: 0.9984 - iou_metric: 0.9329 - val_loss: 0.0038 - val_accuracy: 0.9999 - val_iou_metric: 0.9831 - lr: 2.5000e-05
# Epoch 43/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0180 - accuracy: 0.9984 - iou_metric: 0.9342
# Epoch 43: val_iou_metric improved from 0.98307 to 0.98348, saving model to unet-3d.hdf5
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0180 - accuracy: 0.9984 - iou_metric: 0.9342 - val_loss: 0.0036 - val_accuracy: 0.9999 - val_iou_metric: 0.9835 - lr: 2.5000e-05
# Epoch 44/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0179 - accuracy: 0.9984 - iou_metric: 0.9346
# Epoch 44: val_iou_metric improved from 0.98348 to 0.98376, saving model to unet-3d.hdf5
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0179 - accuracy: 0.9984 - iou_metric: 0.9346 - val_loss: 0.0035 - val_accuracy: 0.9999 - val_iou_metric: 0.9838 - lr: 2.5000e-05
# Epoch 45/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0176 - accuracy: 0.9984 - iou_metric: 0.9356
# Epoch 45: val_iou_metric did not improve from 0.98376
# 230/230 [==============================] - 17s 76ms/step - loss: 0.0176 - accuracy: 0.9984 - iou_metric: 0.9356 - val_loss: 0.0040 - val_accuracy: 0.9998 - val_iou_metric: 0.9817 - lr: 2.5000e-05
# Epoch 46/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0178 - accuracy: 0.9984 - iou_metric: 0.9350
# Epoch 46: val_iou_metric did not improve from 0.98376
# 230/230 [==============================] - 17s 75ms/step - loss: 0.0178 - accuracy: 0.9984 - iou_metric: 0.9350 - val_loss: 0.0034 - val_accuracy: 0.9999 - val_iou_metric: 0.9836 - lr: 2.5000e-05
# Epoch 47/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0194 - accuracy: 0.9983 - iou_metric: 0.9307
# Epoch 47: val_iou_metric improved from 0.98376 to 0.98417, saving model to unet-3d.hdf5
# 230/230 [==============================] - 18s 78ms/step - loss: 0.0194 - accuracy: 0.9983 - iou_metric: 0.9307 - val_loss: 0.0034 - val_accuracy: 0.9999 - val_iou_metric: 0.9842 - lr: 2.5000e-05
# Epoch 48/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0183 - accuracy: 0.9984 - iou_metric: 0.9338
# Epoch 48: val_iou_metric did not improve from 0.98417
# 230/230 [==============================] - 18s 79ms/step - loss: 0.0183 - accuracy: 0.9984 - iou_metric: 0.9338 - val_loss: 0.0068 - val_accuracy: 0.9997 - val_iou_metric: 0.9517 - lr: 2.5000e-05
# Epoch 49/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0177 - accuracy: 0.9984 - iou_metric: 0.9355
# Epoch 49: val_iou_metric improved from 0.98417 to 0.98450, saving model to unet-3d.hdf5
# 230/230 [==============================] - 19s 81ms/step - loss: 0.0177 - accuracy: 0.9984 - iou_metric: 0.9355 - val_loss: 0.0032 - val_accuracy: 0.9999 - val_iou_metric: 0.9845 - lr: 2.5000e-05
# Epoch 50/50
# 230/230 [==============================] - ETA: 0s - loss: 0.0181 - accuracy: 0.9983 - iou_metric: 0.9343
# Epoch 50: val_iou_metric did not improve from 0.98450
# 230/230 [==============================] - 17s 74ms/step - loss: 0.0181 - accuracy: 0.9983 - iou_metric: 0.9343 - val_loss: 0.0033 - val_accuracy: 0.9999 - val_iou_metric: 0.9842 - lr: 2.5000e-05

# %%
# Save model training history
np.save('unet-3d-history.npy',model_unet.history.history)

# %%
# Plot accuracy and loss 

## Accuracy
plt.plot(model_unet.history.history['accuracy'])
plt.plot(model_unet.history.history['val_accuracy'])
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper left')
plt.show()

## Loss
plt.plot(model_unet.history.history['loss'])
plt.plot(model_unet.history.history['val_loss'])
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper left')

# %% [markdown]
# ## Attention U-Net

# %%
# Train Attention U-Net with generator
model_attention_unet = UNetAM(input_size=(512, 512, 3), lr = 0.000055, filter_base=16)
save_model = ModelCheckpoint('unet-3d.hdf5', monitor='val_iou_metric',verbose=1, save_best_only=True, mode='max' )

train = trainGenerator(1, t_images, t_edges, t_masks, data_gen_args)

model_attention_unet.fit(
    train,
    steps_per_epoch=230,
    epochs=60,
    validation_data=([v_images, v_edges], v_masks),
    callbacks=[save_model, reduce_lr]
)
# Out:
# Epoch 1/60
# 230/230 [==============================] - ETA: 0s - loss: 0.3529 - accuracy: 0.8688 - iou_metric: 0.2703
# Epoch 1: val_iou_metric improved from -inf to 0.58688, saving model to unet-3d.hdf5
# 230/230 [==============================] - 19s 73ms/step - loss: 0.3529 - accuracy: 0.8688 - iou_metric: 0.2703 - val_loss: 0.1424 - val_accuracy: 0.9940 - val_iou_metric: 0.5869 - lr: 5.5000e-05
# Epoch 2/60
# 230/230 [==============================] - ETA: 0s - loss: 0.1455 - accuracy: 0.9946 - iou_metric: 0.6049
# Epoch 2: val_iou_metric improved from 0.58688 to 0.64965, saving model to unet-3d.hdf5
# 230/230 [==============================] - 16s 72ms/step - loss: 0.1455 - accuracy: 0.9946 - iou_metric: 0.6049 - val_loss: 0.1194 - val_accuracy: 0.9954 - val_iou_metric: 0.6496 - lr: 5.5000e-05
# Epoch 3/60
# 230/230 [==============================] - ETA: 0s - loss: 0.1090 - accuracy: 0.9955 - iou_metric: 0.6816
# Epoch 3: val_iou_metric improved from 0.64965 to 0.67100, saving model to unet-3d.hdf5
# 230/230 [==============================] - 16s 72ms/step - loss: 0.1090 - accuracy: 0.9955 - iou_metric: 0.6816 - val_loss: 0.1019 - val_accuracy: 0.9955 - val_iou_metric: 0.6710 - lr: 5.5000e-05
# Epoch 4/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0961 - accuracy: 0.9958 - iou_metric: 0.7116
# Epoch 4: val_iou_metric improved from 0.67100 to 0.71669, saving model to unet-3d.hdf5
# 230/230 [==============================] - 17s 73ms/step - loss: 0.0961 - accuracy: 0.9958 - iou_metric: 0.7116 - val_loss: 0.0874 - val_accuracy: 0.9964 - val_iou_metric: 0.7167 - lr: 5.5000e-05
# Epoch 5/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0826 - accuracy: 0.9963 - iou_metric: 0.7452
# Epoch 5: val_iou_metric improved from 0.71669 to 0.74645, saving model to unet-3d.hdf5
# 230/230 [==============================] - 17s 74ms/step - loss: 0.0826 - accuracy: 0.9963 - iou_metric: 0.7452 - val_loss: 0.0770 - val_accuracy: 0.9968 - val_iou_metric: 0.7464 - lr: 5.5000e-05
# Epoch 6/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0769 - accuracy: 0.9965 - iou_metric: 0.7604
# Epoch 6: val_iou_metric improved from 0.74645 to 0.76967, saving model to unet-3d.hdf5
# 230/230 [==============================] - 16s 72ms/step - loss: 0.0769 - accuracy: 0.9965 - iou_metric: 0.7604 - val_loss: 0.0748 - val_accuracy: 0.9972 - val_iou_metric: 0.7697 - lr: 5.5000e-05
# Epoch 7/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0662 - accuracy: 0.9969 - iou_metric: 0.7855
# Epoch 7: val_iou_metric did not improve from 0.76967
# 230/230 [==============================] - 16s 70ms/step - loss: 0.0662 - accuracy: 0.9969 - iou_metric: 0.7855 - val_loss: 0.0831 - val_accuracy: 0.9959 - val_iou_metric: 0.6537 - lr: 5.5000e-05
# Epoch 8/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0589 - accuracy: 0.9971 - iou_metric: 0.8060
# Epoch 8: val_iou_metric improved from 0.76967 to 0.82304, saving model to unet-3d.hdf5
# 230/230 [==============================] - 16s 71ms/step - loss: 0.0589 - accuracy: 0.9971 - iou_metric: 0.8060 - val_loss: 0.0470 - val_accuracy: 0.9980 - val_iou_metric: 0.8230 - lr: 5.5000e-05
# Epoch 9/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0528 - accuracy: 0.9973 - iou_metric: 0.8242
# Epoch 9: val_iou_metric did not improve from 0.82304
# 230/230 [==============================] - 17s 72ms/step - loss: 0.0528 - accuracy: 0.9973 - iou_metric: 0.8242 - val_loss: 0.0427 - val_accuracy: 0.9982 - val_iou_metric: 0.8195 - lr: 5.5000e-05
# Epoch 10/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0479 - accuracy: 0.9975 - iou_metric: 0.8390
# Epoch 10: val_iou_metric improved from 0.82304 to 0.85596, saving model to unet-3d.hdf5
# 230/230 [==============================] - 17s 72ms/step - loss: 0.0479 - accuracy: 0.9975 - iou_metric: 0.8390 - val_loss: 0.0360 - val_accuracy: 0.9985 - val_iou_metric: 0.8560 - lr: 5.5000e-05
# Epoch 11/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0452 - accuracy: 0.9976 - iou_metric: 0.8471
# Epoch 11: val_iou_metric improved from 0.85596 to 0.86126, saving model to unet-3d.hdf5
# 230/230 [==============================] - 17s 74ms/step - loss: 0.0452 - accuracy: 0.9976 - iou_metric: 0.8471 - val_loss: 0.0346 - val_accuracy: 0.9985 - val_iou_metric: 0.8613 - lr: 5.5000e-05
# Epoch 12/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0423 - accuracy: 0.9977 - iou_metric: 0.8567
# Epoch 12: val_iou_metric improved from 0.86126 to 0.89467, saving model to unet-3d.hdf5
# 230/230 [==============================] - 17s 72ms/step - loss: 0.0423 - accuracy: 0.9977 - iou_metric: 0.8567 - val_loss: 0.0277 - val_accuracy: 0.9989 - val_iou_metric: 0.8947 - lr: 5.5000e-05
# Epoch 13/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0377 - accuracy: 0.9979 - iou_metric: 0.8701
# Epoch 13: val_iou_metric improved from 0.89467 to 0.90264, saving model to unet-3d.hdf5
# 230/230 [==============================] - 17s 73ms/step - loss: 0.0377 - accuracy: 0.9979 - iou_metric: 0.8701 - val_loss: 0.0255 - val_accuracy: 0.9990 - val_iou_metric: 0.9026 - lr: 5.5000e-05
# Epoch 14/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0386 - accuracy: 0.9979 - iou_metric: 0.8676
# Epoch 14: val_iou_metric improved from 0.90264 to 0.90562, saving model to unet-3d.hdf5
# 230/230 [==============================] - 16s 72ms/step - loss: 0.0386 - accuracy: 0.9979 - iou_metric: 0.8676 - val_loss: 0.0255 - val_accuracy: 0.9990 - val_iou_metric: 0.9056 - lr: 5.5000e-05
# Epoch 15/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0346 - accuracy: 0.9980 - iou_metric: 0.8797
# Epoch 15: val_iou_metric improved from 0.90562 to 0.90736, saving model to unet-3d.hdf5
# 230/230 [==============================] - 17s 72ms/step - loss: 0.0346 - accuracy: 0.9980 - iou_metric: 0.8797 - val_loss: 0.0232 - val_accuracy: 0.9991 - val_iou_metric: 0.9074 - lr: 5.5000e-05
# Epoch 16/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0345 - accuracy: 0.9980 - iou_metric: 0.8803
# Epoch 16: val_iou_metric did not improve from 0.90736
# 230/230 [==============================] - 16s 72ms/step - loss: 0.0345 - accuracy: 0.9980 - iou_metric: 0.8803 - val_loss: 0.0261 - val_accuracy: 0.9990 - val_iou_metric: 0.9030 - lr: 5.5000e-05
# Epoch 17/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0443 - accuracy: 0.9963 - iou_metric: 0.8591
# Epoch 17: val_iou_metric improved from 0.90736 to 0.91863, saving model to unet-3d.hdf5
# 230/230 [==============================] - 17s 73ms/step - loss: 0.0443 - accuracy: 0.9963 - iou_metric: 0.8591 - val_loss: 0.0214 - val_accuracy: 0.9992 - val_iou_metric: 0.9186 - lr: 5.5000e-05
# Epoch 18/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0326 - accuracy: 0.9980 - iou_metric: 0.8867
# Epoch 18: val_iou_metric did not improve from 0.91863
# 230/230 [==============================] - 16s 70ms/step - loss: 0.0326 - accuracy: 0.9980 - iou_metric: 0.8867 - val_loss: 0.0208 - val_accuracy: 0.9992 - val_iou_metric: 0.9172 - lr: 5.5000e-05
# Epoch 19/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0306 - accuracy: 0.9981 - iou_metric: 0.8926
# Epoch 19: val_iou_metric improved from 0.91863 to 0.92489, saving model to unet-3d.hdf5
# 230/230 [==============================] - 17s 72ms/step - loss: 0.0306 - accuracy: 0.9981 - iou_metric: 0.8926 - val_loss: 0.0192 - val_accuracy: 0.9992 - val_iou_metric: 0.9249 - lr: 5.5000e-05
# Epoch 20/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0296 - accuracy: 0.9981 - iou_metric: 0.8960
# Epoch 20: val_iou_metric improved from 0.92489 to 0.92927, saving model to unet-3d.hdf5
# 230/230 [==============================] - 16s 71ms/step - loss: 0.0296 - accuracy: 0.9981 - iou_metric: 0.8960 - val_loss: 0.0178 - val_accuracy: 0.9993 - val_iou_metric: 0.9293 - lr: 5.5000e-05
# Epoch 21/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0285 - accuracy: 0.9982 - iou_metric: 0.8997
# Epoch 21: val_iou_metric improved from 0.92927 to 0.94051, saving model to unet-3d.hdf5
# 230/230 [==============================] - 17s 72ms/step - loss: 0.0285 - accuracy: 0.9982 - iou_metric: 0.8997 - val_loss: 0.0155 - val_accuracy: 0.9994 - val_iou_metric: 0.9405 - lr: 5.5000e-05
# Epoch 22/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0274 - accuracy: 0.9982 - iou_metric: 0.9030
# Epoch 22: val_iou_metric did not improve from 0.94051
# 230/230 [==============================] - 17s 72ms/step - loss: 0.0274 - accuracy: 0.9982 - iou_metric: 0.9030 - val_loss: 0.0155 - val_accuracy: 0.9994 - val_iou_metric: 0.9372 - lr: 5.5000e-05
# Epoch 23/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0274 - accuracy: 0.9982 - iou_metric: 0.9030
# Epoch 23: val_iou_metric improved from 0.94051 to 0.94487, saving model to unet-3d.hdf5
# 230/230 [==============================] - 17s 72ms/step - loss: 0.0274 - accuracy: 0.9982 - iou_metric: 0.9030 - val_loss: 0.0149 - val_accuracy: 0.9994 - val_iou_metric: 0.9449 - lr: 5.5000e-05
# Epoch 24/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0315 - accuracy: 0.9979 - iou_metric: 0.8929
# Epoch 24: val_iou_metric did not improve from 0.94487
# 230/230 [==============================] - 16s 71ms/step - loss: 0.0315 - accuracy: 0.9979 - iou_metric: 0.8929 - val_loss: 0.0234 - val_accuracy: 0.9991 - val_iou_metric: 0.9120 - lr: 5.5000e-05
# Epoch 25/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0281 - accuracy: 0.9981 - iou_metric: 0.9017
# Epoch 25: val_iou_metric improved from 0.94487 to 0.94743, saving model to unet-3d.hdf5
# 230/230 [==============================] - 17s 74ms/step - loss: 0.0281 - accuracy: 0.9981 - iou_metric: 0.9017 - val_loss: 0.0132 - val_accuracy: 0.9995 - val_iou_metric: 0.9474 - lr: 5.5000e-05
# Epoch 26/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0253 - accuracy: 0.9982 - iou_metric: 0.9098
# Epoch 26: val_iou_metric did not improve from 0.94743
# 230/230 [==============================] - 16s 71ms/step - loss: 0.0253 - accuracy: 0.9982 - iou_metric: 0.9098 - val_loss: 0.0130 - val_accuracy: 0.9995 - val_iou_metric: 0.9462 - lr: 5.5000e-05
# Epoch 27/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0246 - accuracy: 0.9983 - iou_metric: 0.9124
# Epoch 27: val_iou_metric improved from 0.94743 to 0.95078, saving model to unet-3d.hdf5
# 230/230 [==============================] - 16s 69ms/step - loss: 0.0246 - accuracy: 0.9983 - iou_metric: 0.9124 - val_loss: 0.0120 - val_accuracy: 0.9995 - val_iou_metric: 0.9508 - lr: 5.5000e-05
# Epoch 28/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0245 - accuracy: 0.9983 - iou_metric: 0.9129
# Epoch 28: val_iou_metric did not improve from 0.95078
# 230/230 [==============================] - 16s 71ms/step - loss: 0.0245 - accuracy: 0.9983 - iou_metric: 0.9129 - val_loss: 0.0123 - val_accuracy: 0.9995 - val_iou_metric: 0.9494 - lr: 5.5000e-05
# Epoch 29/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0238 - accuracy: 0.9983 - iou_metric: 0.9150
# Epoch 29: val_iou_metric improved from 0.95078 to 0.95254, saving model to unet-3d.hdf5
# 230/230 [==============================] - 17s 73ms/step - loss: 0.0238 - accuracy: 0.9983 - iou_metric: 0.9150 - val_loss: 0.0120 - val_accuracy: 0.9995 - val_iou_metric: 0.9525 - lr: 5.5000e-05
# Epoch 30/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0239 - accuracy: 0.9982 - iou_metric: 0.9147
# Epoch 30: val_iou_metric improved from 0.95254 to 0.95482, saving model to unet-3d.hdf5
# 230/230 [==============================] - 16s 71ms/step - loss: 0.0239 - accuracy: 0.9982 - iou_metric: 0.9147 - val_loss: 0.0114 - val_accuracy: 0.9996 - val_iou_metric: 0.9548 - lr: 5.5000e-05
# Epoch 31/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0272 - accuracy: 0.9982 - iou_metric: 0.9052
# Epoch 31: val_iou_metric improved from 0.95482 to 0.96069, saving model to unet-3d.hdf5
# 230/230 [==============================] - 16s 68ms/step - loss: 0.0272 - accuracy: 0.9982 - iou_metric: 0.9052 - val_loss: 0.0099 - val_accuracy: 0.9996 - val_iou_metric: 0.9607 - lr: 5.5000e-05
# Epoch 32/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0234 - accuracy: 0.9983 - iou_metric: 0.9165
# Epoch 32: val_iou_metric improved from 0.96069 to 0.96224, saving model to unet-3d.hdf5
# 230/230 [==============================] - 15s 66ms/step - loss: 0.0234 - accuracy: 0.9983 - iou_metric: 0.9165 - val_loss: 0.0098 - val_accuracy: 0.9996 - val_iou_metric: 0.9622 - lr: 5.5000e-05
# Epoch 33/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0227 - accuracy: 0.9983 - iou_metric: 0.9184
# Epoch 33: val_iou_metric did not improve from 0.96224
# 230/230 [==============================] - 16s 68ms/step - loss: 0.0227 - accuracy: 0.9983 - iou_metric: 0.9184 - val_loss: 0.0097 - val_accuracy: 0.9996 - val_iou_metric: 0.9598 - lr: 5.5000e-05
# Epoch 34/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0224 - accuracy: 0.9983 - iou_metric: 0.9195
# Epoch 34: val_iou_metric did not improve from 0.96224
# 230/230 [==============================] - 16s 68ms/step - loss: 0.0224 - accuracy: 0.9983 - iou_metric: 0.9195 - val_loss: 0.0111 - val_accuracy: 0.9996 - val_iou_metric: 0.9584 - lr: 5.5000e-05
# Epoch 35/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0220 - accuracy: 0.9983 - iou_metric: 0.9209
# Epoch 35: val_iou_metric improved from 0.96224 to 0.96670, saving model to unet-3d.hdf5
# 230/230 [==============================] - 16s 68ms/step - loss: 0.0220 - accuracy: 0.9983 - iou_metric: 0.9209 - val_loss: 0.0087 - val_accuracy: 0.9997 - val_iou_metric: 0.9667 - lr: 5.5000e-05
# Epoch 36/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0234 - accuracy: 0.9983 - iou_metric: 0.9170
# Epoch 36: val_iou_metric did not improve from 0.96670
# 230/230 [==============================] - 17s 72ms/step - loss: 0.0234 - accuracy: 0.9983 - iou_metric: 0.9170 - val_loss: 0.0091 - val_accuracy: 0.9996 - val_iou_metric: 0.9622 - lr: 5.5000e-05
# Epoch 37/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0229 - accuracy: 0.9983 - iou_metric: 0.9189
# Epoch 37: val_iou_metric did not improve from 0.96670
# 230/230 [==============================] - 16s 69ms/step - loss: 0.0229 - accuracy: 0.9983 - iou_metric: 0.9189 - val_loss: 0.0110 - val_accuracy: 0.9996 - val_iou_metric: 0.9383 - lr: 5.5000e-05
# Epoch 38/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0219 - accuracy: 0.9983 - iou_metric: 0.9213
# Epoch 38: val_iou_metric improved from 0.96670 to 0.96927, saving model to unet-3d.hdf5
# 230/230 [==============================] - 16s 70ms/step - loss: 0.0219 - accuracy: 0.9983 - iou_metric: 0.9213 - val_loss: 0.0078 - val_accuracy: 0.9997 - val_iou_metric: 0.9693 - lr: 5.5000e-05
# Epoch 39/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0215 - accuracy: 0.9983 - iou_metric: 0.9226
# Epoch 39: val_iou_metric did not improve from 0.96927
# 230/230 [==============================] - 17s 72ms/step - loss: 0.0215 - accuracy: 0.9983 - iou_metric: 0.9226 - val_loss: 0.0099 - val_accuracy: 0.9996 - val_iou_metric: 0.9661 - lr: 5.5000e-05
# Epoch 40/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0269 - accuracy: 0.9980 - iou_metric: 0.9096
# Epoch 40: val_iou_metric did not improve from 0.96927
# 230/230 [==============================] - 17s 73ms/step - loss: 0.0269 - accuracy: 0.9980 - iou_metric: 0.9096 - val_loss: 0.0081 - val_accuracy: 0.9997 - val_iou_metric: 0.9671 - lr: 5.5000e-05
# Epoch 41/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0209 - accuracy: 0.9983 - iou_metric: 0.9245
# Epoch 41: val_iou_metric improved from 0.96927 to 0.97238, saving model to unet-3d.hdf5
# 230/230 [==============================] - 17s 72ms/step - loss: 0.0209 - accuracy: 0.9983 - iou_metric: 0.9245 - val_loss: 0.0071 - val_accuracy: 0.9997 - val_iou_metric: 0.9724 - lr: 5.5000e-05
# Epoch 42/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0207 - accuracy: 0.9983 - iou_metric: 0.9254
# Epoch 42: val_iou_metric improved from 0.97238 to 0.97259, saving model to unet-3d.hdf5
# 230/230 [==============================] - 16s 72ms/step - loss: 0.0207 - accuracy: 0.9983 - iou_metric: 0.9254 - val_loss: 0.0071 - val_accuracy: 0.9997 - val_iou_metric: 0.9726 - lr: 5.5000e-05
# Epoch 43/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0205 - accuracy: 0.9983 - iou_metric: 0.9261
# Epoch 43: val_iou_metric improved from 0.97259 to 0.97364, saving model to unet-3d.hdf5
# 230/230 [==============================] - 17s 74ms/step - loss: 0.0205 - accuracy: 0.9983 - iou_metric: 0.9261 - val_loss: 0.0067 - val_accuracy: 0.9997 - val_iou_metric: 0.9736 - lr: 5.5000e-05
# Epoch 44/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0204 - accuracy: 0.9984 - iou_metric: 0.9265
# Epoch 44: val_iou_metric improved from 0.97364 to 0.97365, saving model to unet-3d.hdf5
# 230/230 [==============================] - 16s 71ms/step - loss: 0.0204 - accuracy: 0.9984 - iou_metric: 0.9265 - val_loss: 0.0066 - val_accuracy: 0.9997 - val_iou_metric: 0.9736 - lr: 5.5000e-05
# Epoch 45/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0203 - accuracy: 0.9984 - iou_metric: 0.9262
# Epoch 45: val_iou_metric did not improve from 0.97365
# 230/230 [==============================] - 16s 69ms/step - loss: 0.0203 - accuracy: 0.9984 - iou_metric: 0.9262 - val_loss: 0.0070 - val_accuracy: 0.9997 - val_iou_metric: 0.9702 - lr: 5.5000e-05
# Epoch 46/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0201 - accuracy: 0.9984 - iou_metric: 0.9272
# Epoch 46: val_iou_metric improved from 0.97365 to 0.97595, saving model to unet-3d.hdf5
# 230/230 [==============================] - 16s 70ms/step - loss: 0.0201 - accuracy: 0.9984 - iou_metric: 0.9272 - val_loss: 0.0063 - val_accuracy: 0.9998 - val_iou_metric: 0.9759 - lr: 5.5000e-05
# Epoch 47/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0203 - accuracy: 0.9984 - iou_metric: 0.9262
# Epoch 47: val_iou_metric did not improve from 0.97595
# 230/230 [==============================] - 16s 72ms/step - loss: 0.0203 - accuracy: 0.9984 - iou_metric: 0.9262 - val_loss: 0.0072 - val_accuracy: 0.9997 - val_iou_metric: 0.9682 - lr: 5.5000e-05
# Epoch 48/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0261 - accuracy: 0.9980 - iou_metric: 0.9142
# Epoch 48: val_iou_metric did not improve from 0.97595
# 230/230 [==============================] - 16s 69ms/step - loss: 0.0261 - accuracy: 0.9980 - iou_metric: 0.9142 - val_loss: 0.0074 - val_accuracy: 0.9997 - val_iou_metric: 0.9694 - lr: 5.5000e-05
# Epoch 49/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0199 - accuracy: 0.9983 - iou_metric: 0.9278
# Epoch 49: val_iou_metric did not improve from 0.97595
# 230/230 [==============================] - 16s 71ms/step - loss: 0.0199 - accuracy: 0.9983 - iou_metric: 0.9278 - val_loss: 0.0062 - val_accuracy: 0.9998 - val_iou_metric: 0.9736 - lr: 5.5000e-05
# Epoch 50/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0198 - accuracy: 0.9983 - iou_metric: 0.9283
# Epoch 50: val_iou_metric did not improve from 0.97595
# 230/230 [==============================] - 16s 71ms/step - loss: 0.0198 - accuracy: 0.9983 - iou_metric: 0.9283 - val_loss: 0.0068 - val_accuracy: 0.9998 - val_iou_metric: 0.9754 - lr: 5.5000e-05
# Epoch 51/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0200 - accuracy: 0.9984 - iou_metric: 0.9275
# Epoch 51: val_iou_metric did not improve from 0.97595
# 230/230 [==============================] - 16s 71ms/step - loss: 0.0200 - accuracy: 0.9984 - iou_metric: 0.9275 - val_loss: 0.0061 - val_accuracy: 0.9998 - val_iou_metric: 0.9741 - lr: 5.5000e-05
# Epoch 52/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0194 - accuracy: 0.9984 - iou_metric: 0.9294
# Epoch 52: val_iou_metric improved from 0.97595 to 0.97619, saving model to unet-3d.hdf5
# 230/230 [==============================] - 16s 71ms/step - loss: 0.0194 - accuracy: 0.9984 - iou_metric: 0.9294 - val_loss: 0.0058 - val_accuracy: 0.9998 - val_iou_metric: 0.9762 - lr: 5.5000e-05
# Epoch 53/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0196 - accuracy: 0.9984 - iou_metric: 0.9288
# Epoch 53: val_iou_metric improved from 0.97619 to 0.97651, saving model to unet-3d.hdf5
# 230/230 [==============================] - 17s 73ms/step - loss: 0.0196 - accuracy: 0.9984 - iou_metric: 0.9288 - val_loss: 0.0058 - val_accuracy: 0.9998 - val_iou_metric: 0.9765 - lr: 5.5000e-05
# Epoch 54/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0196 - accuracy: 0.9984 - iou_metric: 0.9287
# Epoch 54: val_iou_metric did not improve from 0.97651
# 230/230 [==============================] - 16s 71ms/step - loss: 0.0196 - accuracy: 0.9984 - iou_metric: 0.9287 - val_loss: 0.0059 - val_accuracy: 0.9998 - val_iou_metric: 0.9760 - lr: 5.5000e-05
# Epoch 55/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0197 - accuracy: 0.9984 - iou_metric: 0.9285
# Epoch 55: val_iou_metric improved from 0.97651 to 0.97781, saving model to unet-3d.hdf5
# 230/230 [==============================] - 17s 72ms/step - loss: 0.0197 - accuracy: 0.9984 - iou_metric: 0.9285 - val_loss: 0.0053 - val_accuracy: 0.9998 - val_iou_metric: 0.9778 - lr: 5.5000e-05
# Epoch 56/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0193 - accuracy: 0.9984 - iou_metric: 0.9298
# Epoch 56: val_iou_metric improved from 0.97781 to 0.97792, saving model to unet-3d.hdf5
# 230/230 [==============================] - 16s 71ms/step - loss: 0.0193 - accuracy: 0.9984 - iou_metric: 0.9298 - val_loss: 0.0054 - val_accuracy: 0.9998 - val_iou_metric: 0.9779 - lr: 5.5000e-05
# Epoch 57/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0195 - accuracy: 0.9983 - iou_metric: 0.9291
# Epoch 57: val_iou_metric did not improve from 0.97792
# 230/230 [==============================] - 15s 66ms/step - loss: 0.0195 - accuracy: 0.9983 - iou_metric: 0.9291 - val_loss: 0.0053 - val_accuracy: 0.9998 - val_iou_metric: 0.9773 - lr: 5.5000e-05
# Epoch 58/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0190 - accuracy: 0.9984 - iou_metric: 0.9306
# Epoch 58: val_iou_metric improved from 0.97792 to 0.97955, saving model to unet-3d.hdf5
# 230/230 [==============================] - 15s 66ms/step - loss: 0.0190 - accuracy: 0.9984 - iou_metric: 0.9306 - val_loss: 0.0049 - val_accuracy: 0.9998 - val_iou_metric: 0.9796 - lr: 5.5000e-05
# Epoch 59/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0189 - accuracy: 0.9984 - iou_metric: 0.9312
# Epoch 59: val_iou_metric improved from 0.97955 to 0.97975, saving model to unet-3d.hdf5
# 230/230 [==============================] - 15s 67ms/step - loss: 0.0189 - accuracy: 0.9984 - iou_metric: 0.9312 - val_loss: 0.0050 - val_accuracy: 0.9998 - val_iou_metric: 0.9798 - lr: 5.5000e-05
# Epoch 60/60
# 230/230 [==============================] - ETA: 0s - loss: 0.0187 - accuracy: 0.9984 - iou_metric: 0.9315
# Epoch 60: val_iou_metric improved from 0.97975 to 0.98114, saving model to unet-3d.hdf5
# 230/230 [==============================] - 15s 67ms/step - loss: 0.0187 - accuracy: 0.9984 - iou_metric: 0.9315 - val_loss: 0.0046 - val_accuracy: 0.9998 - val_iou_metric: 0.9811 - lr: 5.5000e-05

# %%
# Save model history
np.save('unet-attention-3d-history.npy',model_attention_unet.history.history)

# %% [markdown]
# # Import Models and Compute Metrics

# %% [markdown]
# ## RGB

# %%
# Load 3-dim models and history stats
attention_unet = load_model(
    'unet-attention-3d.hdf5',
    custom_objects={
        'iou_metric': iou_metric,
        'bce_dice_loss_weighted': bce_dice_loss_weighted
    }
)

unet = load_model(
    'unet-3d.hdf5',
    custom_objects={'iou_metric': iou_metric,
                    'bce_dice_loss_weighted': bce_dice_loss_weighted
                   }
)

unet_history = np.load('unet-3d-history.npy', allow_pickle='TRUE').item()
attention_unet_history = np.load('unet-attention-3d-history.npy', allow_pickle='TRUE').item()

# %%
# Plot accuracy and loss for U-Net

## Accuracy

plt.plot(unet_history['iou_metric'])
plt.plot(unet_history['val_iou_metric'])

plt.ylabel('IoU')
plt.xlabel('Epoch')
plt.legend(['Unet Training IoU', 'Unet Validation IoU'], loc='upper left')
plt.grid(True)
plt.show()


## Loss
plt.plot(unet_history['loss'])
plt.plot(unet_history['val_loss'])
plt.ylabel('Loss', size=12)
plt.xlabel('Epoch', size=12)
plt.legend(['Unet Training Loss', 'Unet Validation Loss'], loc='lower right')

# %%
# Plot accuracy and loss for Attention U-Net

## Accuracy

plt.plot(attention_unet_history['iou_metric'])
plt.plot(attention_unet_history['val_iou_metric'])

plt.ylabel('IoU')
plt.xlabel('Epoch')
plt.legend(['Attention Unet Training IoU', 'Attention Unet Validation IoU'], loc='upper left')
plt.grid(True)
plt.show()


## Loss
plt.plot(attention_unet_history['loss'])
plt.plot(attention_unet_history['val_loss'])
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Attention Unet Training Loss', 'Attention Unet Validation Loss'], loc='upper right')

# %%
def model_predict(model, image, edge=None):
    if len(model.inputs) == 2:
        return model.predict([image, edge])
    else:
        return model.predict(image)
def score_eval(model, images, masks, edges=None):
    scores = []

    num_inputs = len(model.inputs)

    for i in range(len(images)):
        img = images[i].reshape(1, 512, 512, 3)

        if num_inputs == 1:
            pred = model.predict(img)

        elif num_inputs == 2:
            edg = edges[i].reshape(1, 512, 512, 1)
            pred = model.predict([img, edg])

        pred = np.round(pred).flatten()
        true = masks[i].flatten()

        scores.append(accuracy_score(true, pred))

    return scores

def recall_eval(model, images, masks, edges):
    recalls = []

    for i in range(len(images)):
        pred = model_predict(model,
                             images[i].reshape(1,512,512,3),
                             edges[i].reshape(1,512,512,1))[0]

        pred = np.round(pred).flatten()
        gt = masks[i].flatten()

        recalls.append(recall_score(gt, pred, average='binary', zero_division=0))

    return recalls
def precision_eval(model, images, masks, edges=None):
    precision = []

    for i in range(len(images)):
        img = images[i].reshape(1,512,512,3)

        if edges is not None:
            ed = edges[i].reshape(1,512,512,1)
        else:
            ed = None

        pred = model_predict(model, img, ed)[0]
        pred = np.round(pred).flatten()

        precision.append(precision_score(masks[i].flatten(), pred, average='weighted'))

    return precision


def f1_score_eval(model, images, masks, edges):
    prec = np.mean(precision_eval(model, images, masks, edges))
    rec  = np.mean(recall_eval(model, images, masks, edges))

    if prec + rec == 0:
        return 0
    return 2 * prec * rec / (prec + rec)

def produce_mask(image): # Outputs rounded image (binary)
  return np.round(image)

# %%
unet_score = score_eval(unet, validation_images, validation_masks, edges=validation_edges)
am_unet_score = score_eval(attention_unet, validation_images, validation_masks, edges=validation_edges)

# %%
# Precision and recall of each model
unet_precision = (precision_eval(unet, validation_images, validation_masks, edges=validation_edges))
am_unet_precision = (precision_eval(attention_unet, validation_images, validation_masks, edges=validation_edges))

unet_recall = (recall_eval(unet, validation_images, validation_masks, edges=validation_edges))
am_unet_recall = (recall_eval(attention_unet, validation_images, validation_masks, edges=validation_edges))

# %%
# F1-scores of each model
unet_f1_score = (f1_score_eval(unet, validation_images, validation_masks, edges=validation_edges))
am_unet_f1_score = (f1_score_eval(attention_unet, validation_images, validation_masks, edges=validation_edges))

# %%
# Print score eval results for each model
print('U-Net accuracy: ', np.mean(unet_score), np.std(unet_score))
print('Attention U-Net accuracy: ', np.mean(am_unet_score), np.std(am_unet_score))

# %%
# Print precision eval results for each model
print('U-Net precision: ', np.mean(unet_precision), np.std(unet_precision))
print('Attention U-Net precision: ', np.mean(am_unet_precision), np.std(am_unet_precision))

# %%
# Print recall eval results for each model
print('U-Net recall: ', np.mean(unet_recall), np.std(unet_recall))
print('Attention U-Net recall: ', np.mean(am_unet_recall), np.std(am_unet_recall))

# %%
# Print f1-score eval results for each model
print('U-Net F1-score: ', np.mean(unet_f1_score))
print('Attention U-Net F1-score: ', np.mean(am_unet_f1_score))
